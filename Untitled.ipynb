# %%
import xarray as xr
import numpy as np
import os
from glob import glob
sys.path.appen
import utils
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /local/w40/ab2313/tmp/ipykernel_3185873/3458386724.py in <cell line: 5>()
#       3 import os
#       4 from glob import glob
# ----> 5 import utils
#       6 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'utils'

# %%
CO21PCT_PATH = '/g/data/oi10/replicas/CMIP6/C4MIP'

# %%
fpahts_1pct = glob(os.path.join(CO21PCT_PATH, '**/*1pctCO2*.nc'), recursive=True)

# %%
fpahts_1pct[:3]
# Out:
# ['/g/data/oi10/replicas/CMIP6/C4MIP/MPI-M/MPI-ESM1-2-LR/1pctCO2-bgc/r2i1p1f1/Amon/rsut/gn/v20190710/rsut_Amon_MPI-ESM1-2-LR_1pctCO2-bgc_r2i1p1f1_gn_193001-194912.nc',
#  '/g/data/oi10/replicas/CMIP6/C4MIP/MPI-M/MPI-ESM1-2-LR/1pctCO2-bgc/r2i1p1f1/Amon/rsut/gn/v20190710/rsut_Amon_MPI-ESM1-2-LR_1pctCO2-bgc_r2i1p1f1_gn_189001-190912.nc',
#  '/g/data/oi10/replicas/CMIP6/C4MIP/MPI-M/MPI-ESM1-2-LR/1pctCO2-bgc/r2i1p1f1/Amon/rsut/gn/v20190710/rsut_Amon_MPI-ESM1-2-LR_1pctCO2-bgc_r2i1p1f1_gn_195001-196912.nc',
#  '/g/data/oi10/replicas/CMIP6/C4MIP/MPI-M/MPI-ESM1-2-LR/1pctCO2-bgc/r2i1p1f1/Amon/rsut/gn/v20190710/rsut_Amon_MPI-ESM1-2-LR_1pctCO2-bgc_r2i1p1f1_gn_187001-188912.nc',
#  '/g/data/oi10/replicas/CMIP6/C4MIP/MPI-M/MPI-ESM1-2-LR/1pctCO2-bgc/r2i1p1f1/Amon/rsut/gn/v20190710/rsut_Amon_MPI-ESM1-2-LR_1pctCO2-bgc_r2i1p1f1_gn_197001-198912.nc',
# ...
