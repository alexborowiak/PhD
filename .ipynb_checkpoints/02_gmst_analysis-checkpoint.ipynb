# %% [markdown]
# # SN Global
# This notebook contains:
# * First analysis of SN on global level.

# %% [markdown]
# # Preamble

# %%
import numpy as np
import os
import itertools
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
import xarray as xr
from importlib import reload
import cartopy.crs as ccrs
import matplotlib.ticker as mticker
from dask.diagnostics import ProgressBar

# %%
import sys
# Contains path information
import constants

sys.path.append(constants.MODULE_DIR)

# Custom xarray classes that addes different method.
import xarray_class_accessors as xca

# Custom plots for signal to noise functions.
import sn_plotting as sn_plot

# %%
# The directory where all of the longrun mip data used in this notebook is stored.
ROOT_DIR = constants.LONGRUNMIP_DIR
ROOT_DIR

# %%
IMG_DIR = os.path.join(constants.IMAGE_SAVE_DIR, 'PhD/init')
IMG_DIR
# Out:
# '/home/563/ab2313/Documents/images/PhD/init'

# %%
model = 'CCSM3'

# %% [markdown]
# # Control
# THe SN for the piControl is get the stable/unstable bounds for each gridcell. This is to work out what can be considered natural variabilbity of the system.

# %%
control = xr.open_dataset(os.path.join(ROOT_DIR,'tas_mon_CCSM3_control_1530.nc' )).tas

# Applying corrections.
control = control.correct_data.apply_corrections()

# Only want the yearly average. This needs to be done after corrections. 
control = control.resample(time='Y').mean()
control
# Out:
# Testing months in each year...
# Inital time length: 18360
# - First year removed: 11 month(s) in year 1
# - Last year removed:  1 month(s) in year 1531
#
# Data Correction complete - all years now have 12 months
# Final time length: 18348
# <xarray.DataArray 'tas' (time: 1529, lat: 48, lon: 96)>
# array([[[235.86493, 235.50179, 235.13353, ..., 236.84892, 236.5406 ,
#          236.21118],
#         [238.37079, 237.22215, 236.04646, ..., 241.35016, 240.44713,
#          239.43877],
#         [239.8416 , 237.90228, 235.96063, ..., 245.24316, 243.58911,
#          241.77766],
#         ...,
#         [263.8774 , 265.18118, 265.90146, ..., 260.20456, 261.0649 ,
#          262.254  ],
#         [259.6686 , 260.0328 , 260.38202, ..., 258.26068, 258.76355,
#          259.19073],
#         [257.916  , 258.03632, 258.14853, ..., 257.6398 , 257.74213,
#          257.83652]],
#
#        [[235.3564 , 235.00415, 234.61969, ..., 236.33803, 236.03725,
#          235.70268],
#         [238.57758, 237.47261, 236.32445, ..., 241.50392, 240.60963,
#          239.63506],
#         [240.41597, 238.6551 , 236.8991 , ..., 245.48674, 243.87451,
#          242.17317],
# ...
#         [261.66296, 262.09494, 261.9867 , ..., 257.4562 , 258.64508,
#          260.29572],
#         [255.53589, 255.74329, 255.88863, ..., 254.16583, 254.63136,
#          255.0341 ],
#         [254.41034, 254.4991 , 254.58026, ..., 254.20654, 254.28532,
#          254.35356]],
#
#        [[233.48418, 233.03755, 232.58012, ..., 234.77235, 234.35268,
#          233.93048],
#         [235.1908 , 233.85356, 232.4763 , ..., 238.80861, 237.67389,
#          236.47026],
#         [237.7293 , 235.61786, 233.48466, ..., 243.38203, 241.64429,
#          239.75859],
#         ...,
#         [259.55725, 259.8377 , 259.89133, ..., 257.08185, 258.07437,
#          258.9237 ],
#         [254.2987 , 254.48146, 254.70123, ..., 253.26869, 253.6573 ,
#          253.95363],
#         [253.09596, 253.20906, 253.30907, ..., 252.81451, 252.92323,
#          253.01819]]], dtype=float32)
# Coordinates:
#   * time     (time) object 0002-12-31 00:00:00 ... 1530-12-31 00:00:00
#   * lat      (lat) float64 -87.16 -83.48 -79.78 -76.07 ... 79.78 83.48 87.16
#   * lon      (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2

# %%
# Getting the anomalies for the control run. The anomalies are caculated from the start and 
# the end of the run.
control_anom = control.clima.anomalies(start = control.time.dt.year.values[0], 
                                          end = control.time.dt.year.values[-1])
control_anom
# Out:
# <xarray.DataArray 'tas' (time: 1529, lat: 48, lon: 96)>
# dask.array<xarray-<this-array>, shape=(1529, 48, 96), dtype=float32, chunksize=(8, 48, 96), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 0002-12-31 00:00:00 ... 1530-12-31 00:00:00
#   * lat      (lat) float64 -87.16 -83.48 -79.78 -76.07 ... 79.78 83.48 87.16
#   * lon      (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2

# %%
fig,(ax1,ax2,ax3) = plt.subplots(3, figsize=(8, 14))
control_anom.isel(time=0).plot(ax=ax1)
control_anom.isel(time=8).plot(ax=ax2)
control_anom.isel(time=20).plot(ax=ax3)

# %% [markdown]
# # QuadCO2
# Running the same codes as above, but for a run where the CO2 has been quadrupled.

# %%
abrupt = xr.open_dataset(os.path.join(ROOT_DIR,'tas_mon_CCSM3_abrupt4x_2120.nc' )).tas

abrupt = abrupt.correct_data.apply_corrections()

abrupt = abrupt.resample(time='Y').mean()
abrupt
# Out:
# Testing months in each year...
# Inital time length: 25440
# - First year removed: 11 month(s) in year 1
# - Last year removed:  1 month(s) in year 2121
# - Incorrect year detected and time overridden
#
# Data Correction complete - all years now have 12 months
# Final time length: 25428
# <xarray.DataArray 'tas' (time: 2119, lat: 48, lon: 96)>
# array([[[238.17262, 237.81415, 237.4554 , ..., 239.1385 , 238.8279 ,
#          238.50989],
#         [240.75873, 239.70117, 238.63087, ..., 243.5872 , 242.70825,
#          241.76225],
#         [242.45258, 240.6974 , 238.99084, ..., 247.44733, 245.88509,
#          244.20746],
#         ...,
#         [262.82187, 264.01248, 264.89276, ..., 261.59412, 261.6085 ,
#          262.00278],
#         [260.01486, 260.19543, 260.38647, ..., 259.27866, 259.56528,
#          259.77042],
#         [259.1821 , 259.24893, 259.3114 , ..., 259.05426, 259.10065,
#          259.13828]],
#
#        [[236.11565, 235.787  , 235.43633, ..., 237.04193, 236.75072,
#          236.44154],
#         [238.8268 , 237.8432 , 236.84479, ..., 241.58934, 240.73964,
#          239.8091 ],
#         [240.69069, 239.06734, 237.50099, ..., 245.6093 , 244.02362,
#          242.36903],
# ...
#         [271.12576, 271.3906 , 271.444  , ..., 268.50244, 269.7305 ,
#          270.5875 ],
#         [267.8196 , 267.98868, 268.12393, ..., 266.86157, 267.26968,
#          267.56277],
#         [266.82373, 266.8773 , 266.92075, ..., 266.59106, 266.68405,
#          266.76785]],
#
#        [[241.1106 , 240.7738 , 240.43372, ..., 242.04884, 241.74658,
#          241.43355],
#         [244.29964, 243.29948, 242.2906 , ..., 247.20032, 246.26624,
#          245.28731],
#         [246.07825, 244.34969, 242.72267, ..., 251.67986, 249.80945,
#          247.9226 ],
#         ...,
#         [271.35434, 271.63284, 271.68005, ..., 269.0222 , 269.98453,
#          270.77737],
#         [267.91116, 268.19626, 268.4202 , ..., 266.73145, 267.15375,
#          267.52435],
#         [267.3329 , 267.40015, 267.4672 , ..., 267.05527, 267.15005,
#          267.25082]]], dtype=float32)
# Coordinates:
#   * time     (time) object 0002-12-31 00:00:00 ... 2120-12-31 00:00:00
#   * lat      (lat) float64 -87.16 -83.48 -79.78 -76.07 ... 79.78 83.48 87.16
#   * lon      (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2

# %%
abrupt.time.values[:3]
# Out:
# array([cftime.DatetimeNoLeap(2, 12, 31, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(3, 12, 31, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(4, 12, 31, 0, 0, 0, 0, has_year_zero=True)],
#       dtype=object)

# %%
# Getting the temperature anomalies. The start and end year are the start and of the control
# period. The anomalies are compared to the control run here.
abrupt_anom = abrupt.clima.anomalies(start = control.time.dt.year.values[0], 
                                          end = control.time.dt.year.values[-1],
                            historical = control)
# Out:
# Using historical dataset

# %%
abrupt_anom
# Out:
# <xarray.DataArray 'tas' (time: 2119, lat: 48, lon: 96)>
# dask.array<xarray-<this-array>, shape=(2119, 48, 96), dtype=float32, chunksize=(8, 48, 96), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 0002-12-31 00:00:00 ... 2120-12-31 00:00:00
#   * lat      (lat) float64 -87.16 -83.48 -79.78 -76.07 ... 79.78 83.48 87.16
#   * lon      (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2

# %% [markdown]
# # Global Mean

# %% [markdown]
# Calculating the s/n for the global mean. Each grid cell is then compared with the global mean.

# %% [markdown]
# ## Control Bounds

# %%
control_anom
# Out:
# <xarray.DataArray 'tas' (time: 1529, lat: 48, lon: 96)>
# dask.array<xarray-<this-array>, shape=(1529, 48, 96), dtype=float32, chunksize=(8, 48, 96), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 0002-12-31 00:00:00 ... 1530-12-31 00:00:00
#   * lat      (lat) float64 -87.16 -83.48 -79.78 -76.07 ... 79.78 83.48 87.16
#   * lon      (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2

# %%
# Getting the space mean of the anomalies.
control_anom_smean = control_anom.clima.space_mean()
control_anom_smean
# Out:
# <xarray.DataArray 'tas' (time: 1529)>
# dask.array<truediv, shape=(1529,), dtype=float64, chunksize=(8,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 0002-12-31 00:00:00 ... 1530-12-31 00:00:00

# %%
control_anom_smean.plot()

# %%
control_anom_smean = control_anom_smean.isel(time=slice(12,None))
control_anom_smean.plot()

# %%
# The mean signal of the anomalies.
control_anom_smean_signal = control_anom_smean.sn.signal_grad()
control_anom_smean_signal.plot()

# %%
# Applying the loess filter to the space mean anomalies.
control_anom_smean_loess = control_anom_smean.sn.loess_grid()
control_anom_smean_loess.plot()

# %%
control_anom_smean_noise = control_anom_smean_loess.sn.noise_grad()
control_anom_smean_noise.plot()

# %%
control_anom_smean_sn = control_anom_smean_signal/control_anom_smean_noise
control_anom_smean_sn.plot()

# %%
control_anom_smean_sn
# Out:
# <xarray.DataArray (time: 1457)>
# dask.array<truediv, shape=(1457,), dtype=float64, chunksize=(64,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 0014-12-31 00:00:00 ... 1470-12-31 00:00:00

# %%
# The lower and upper bounds of what is defined as a normal climate.
control_smean_ubound = control_anom_smean_sn.reduce(np.nanpercentile, q=99, dim='time')
control_smean_lbound = control_anom_smean_sn.reduce(np.nanpercentile, q=1, dim='time')
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/dask/array/core.py:1503: FutureWarning: The `numpy.nanpercentile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/dask/array/core.py:1503: FutureWarning: The `numpy.nanpercentile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(

# %%
fig = plt.figure(figsize=(12,4))
ax = plt.gca()
control_anom_smean_sn.plot(label='Signal/Noise', ax=ax, color='green', alpha=0.8)
control_anom_smean.plot(label='GMST', ax=ax, color='blue', alpha=0.8)
ax.legend()

ax.set_title('piControl GMST and S/N')

fig.savefig(f'{IMG_DIR}/02_piControl_SN.png', dpi=200)

# %%
print(control_smean_lbound.values, control_smean_ubound.values)
# Out:
# -1.9529636653003202 1.5499196171047467

# %% [markdown]
# ## Abrupt Values

# %%
abrupt_anom_smean = abrupt_anom.clima.space_mean()
abrupt_anom_smean.plot()

# %%
fig = plt.figure(figsize=(12,6))
ax = plt.gca()
abrupt_anom_smean.plot(ax = ax, color='green', alpha = 0.8)
ax.set_xlim(abrupt_anom_smean.time.values[0], abrupt_anom_smean.time.values[-1])
ax.set_xlabel('Time', size=14)
ax.set_ylabel('GMST', size=14)
fig.savefig(f'{IMG_DIR}/02_GMST.png', dpi=200)

# %%
sample_period = (0,61)
window_length = np.diff(sample_period)[0]
# sample_period = (1200,1261)

# %%
sample_data = abrupt_anom_smean.isel(time=slice(*sample_period))
sample_data
# Out:
# <xarray.DataArray 'tas' (time: 61)>
# dask.array<getitem, shape=(61,), dtype=float64, chunksize=(8,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 0002-12-31 00:00:00 ... 0062-12-31 00:00:00

# %%
gradient_sp, yintercept_sp = xca.SignalToNoise._grid_trend(sample_data.values, use=[0,1])
print(gradient_sp, yintercept_sp)
# Out:
# 0.015318290610986553 2.866117233121977

# %%
x_values = np.arange(len(sample_data.time.values))
fitted_line = gradient_sp * x_values + yintercept_sp
fitted_line[:5]
# Out:
# array([2.86611723, 2.88143552, 2.89675381, 2.9120721 , 2.9273904 ])

# %%
abrupt_anom_smean_signal = abrupt_anom_smean.sn.signal_grad()
abrupt_anom_smean_signal.plot()

# %%
signal_sp = gradient_sp * window_length
signal_sp
# Out:
# 0.9344157272701797

# %%
abrupt_anom_smean_signal.isel(time=0).values
# Out:
# array(0.93441573)

# %%
fig = plt.figure(figsize=(12,6))
ax = plt.gca()
sample_data.plot(ax = ax, color='green', alpha = 0.8, marker='o', label='GMST')
ax.plot(sample_data.time.values, fitted_line, label=f'Linear Trend Line\nGrad = {gradient_sp:.2f}\nSignal {signal_sp:.2f}')
ax.set_xlim(sample_data.time.values[0], sample_data.time.values[-1])
ax.set_xlabel('Time', size=14)
ax.set_ylabel('GMST', size=14)
# ax.legend(ncol=2);


c_gmst = plt.gca().lines[0].get_color()
ax.annotate('GMST', xy = (0.35, 0.7), xycoords='axes fraction', size=15, c=c_gmst, alpha=0.8,
            xytext = (0.25, 0.8),
           arrowprops=dict(facecolor=c_gmst, shrink=0.05, alpha=0.8))


c_line = plt.gca().lines[1].get_color()
ax.annotate(f'Linear Trend Line\nGrad   = {gradient_sp:.2f}\nSignal = {gradient_sp:.2f} * {window_length}\n           = {signal_sp:.2f}',
            xy = (0.37, 0.51), xycoords='axes fraction', size=15, c=c_line, alpha=0.8,
            xytext = (0.45, 0.2),
           arrowprops=dict(facecolor=c_line, shrink=0.05, alpha=0.8))

fig.savefig(f'{IMG_DIR}/02_GMST_Signal.png', dpi=200)

# %%
abrupt_anom_smean_loess = abrupt_anom_smean.sn.loess_grid()
abrupt_anom_smean_loess.plot()

# %%
yhat = xca.SignalToNoise.loess_filter(abrupt_anom_smean.values, step_size = 61)

plt.plot(yhat)

# %%
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,1,1)
abrupt_anom_smean.isel(time=slice(*sample_period)).plot(ax=ax1, label='Original', color='green', marker='o'
                                                       ,alpha=0.8)
ax1.plot(sample_data.time.values[sample_period[0]:sample_period[-1]],
         yhat[sample_period[0]:sample_period[-1]], label='Lowess Smoothed', color='blue',alpha=0.8)
ax1.set_ylim([2.4,4])
ax1.set_title('Original', fontsize=14)
ax1.set_xlabel('')
ax1.tick_params(axis='x', bottom=False, labelbottom=False)
ax1.legend()

ax2 = fig.add_subplot(2,1,2)
abrupt_anom_smean_loess.isel(time=slice(*sample_period)).plot(ax=ax2, color='green', marker='o',alpha=0.8)
ax2.set_ylim([-0.6, 1])
ax2.set_title('Lowess Smoothed De-trended', fontsize=14)
ax2.set_xlabel('Time', fontsize=12)

ax1.set_xlim(sample_data.time.values[0], sample_data.time.values[-1]);
ax2.set_xlim(sample_data.time.values[0], sample_data.time.values[-1]);

fig.savefig(f'{IMG_DIR}/02_GMST_lowess.png', dpi=200)

# %%
abrupt_anom_smean_noise = abrupt_anom_smean_loess.sn.noise_grad()
abrupt_anom_smean_noise.plot()

# %%
abrupt_anom_smean_noise.isel(time=0).values
# Out:
# array(0.10225974)

# %%
abrupt_anom_smean_noise.isel(time=slice(*sample_period)).plot()

# %%
abrupt_anom_smean_sn = abrupt_anom_smean_signal/abrupt_anom_smean_noise
abrupt_anom_smean_sn.plot()

# %%
sample_period_2 = (0, 20000)

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(211)

abrupt_anom_smean_signal.isel(time=slice(*sample_period_2)).plot(ax=ax, color='green')
abrupt_anom_smean_noise.isel(time=slice(*sample_period_2)).plot(ax = ax, color='blue')

ax2 = fig.add_subplot(212)
abrupt_anom_smean_sn.isel(time=slice(*sample_period_2)).plot(ax = ax2, color='darkred')

fig.savefig(f'{IMG_DIR}/02_GMST_Signal_Npng', dpi=200)

# %% [markdown]
# ## Global Average Stable Bounds

# %%
abrupt_anom_smean_sn
# Out:
# <xarray.DataArray (time: 2059)>
# dask.array<truediv, shape=(2059,), dtype=float64, chunksize=(64,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 0002-12-31 00:00:00 ... 2060-12-31 00:00:00

# %%
# SN
# The global mean signal-to-noise points that are stable
abrupt_anom_smean_sn_stable = abrupt_anom_smean_sn.where(
    np.logical_and(
                        abrupt_anom_smean_sn <= control_smean_ubound,
                        abrupt_anom_smean_sn >= control_smean_lbound 
                            )
                                  )

# TEMP
# The global mean temperature anomalies that are stable
abrupt_anom_smean_stable = abrupt_anom_smean.where(
    np.logical_and(
                        abrupt_anom_smean_sn <= control_smean_ubound,
                        abrupt_anom_smean_sn >= control_smean_lbound 
                            )
                                  )

# %%
sn_plot.temperature_vs_sn_plot
# Out:
# <function sn_plotting.temperature_vs_sn_plot(ax, sn, temp, temp_highlight=None, sn_highlight=None)>

# %%
reload(sn_plot)
# Out:
# <module 'sn_plotting' from '/home/563/ab2313/Documents/PhD/init/sn_plotting.py'>

# %%
fig = plt.figure(figsize=  (15,10))
ax = fig.add_subplot(111)
sn_plot.temperature_vs_sn_plot(ax,  abrupt_anom_smean_sn, abrupt_anom_smean,
                      temp_highlight = abrupt_anom_smean_stable, 
                      sn_highlight = abrupt_anom_smean_sn_stable)
fig.savefig(f'{IMG_DIR}/02_{model}_global_sn_temp_anomaly.png', bbox_inches='tight', dpi=500)

# %%
control_anom_smean_sn
# Out:
# <xarray.DataArray (time: 1457)>
# dask.array<truediv, shape=(1457,), dtype=float64, chunksize=(64,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 0014-12-31 00:00:00 ... 1470-12-31 00:00:00

# %%
#The consecutive metrics
stable_smean_ds = abrupt_anom_smean_sn_stable.sn.calculate_consecutive_metrics().compute()

# %%
stable_smean_ds.first_stable.values
# Out:
# array(57.)

# %%
stable_smean_ds
# Out:
# <xarray.Dataset>
# Dimensions:              ()
# Coordinates:
#     time                 object 0002-12-31 00:00:00
# Data variables:
#     first_stable         float64 57.0
#     average_length       float64 57.11
#     number_periods       float64 28.0
#     total_time_stable    float64 1.599e+03
#     percent_time_stable  float64 77.66
