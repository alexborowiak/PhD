# %% [markdown]
# # Local ToE
#
# - In this version I have added in the other tests (KS, Anerson Darling)

# %%
# Standard Library Imports
import os
import sys
from importlib import reload
from functools import partial
from itertools import groupby

# Third-Party Library Imports
import numpy as np
import dask.array
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.colors as mcolors
import cartopy.crs as ccrs
from scipy.stats import ttest_ind


from numpy.typing import ArrayLike
from typing import Callable

# My imports
import os, sys
sys.path.append(os.path.join(os.getcwd(), 'Documents', 'PhD'))
import constants
sys.path.append(constants.MODULE_DIR)
               
import utils
import signal_to_noise as sn
import plotting_functions
import xarray_extender as xe
import stats

# Suppress Warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# Matplotlib created a temporary config/cache directory at /jobfs/111125610.gadi-pbs/matplotlib-9odisfww because the default path (/home/563/ab2313/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
import time_of_emrgence_calc as toe

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1)
client.cluster.scale(50)
client
# Out:
# KeyboardInterrupt

# %%
xr.set_options(display_expand_attrs=False)
xr.set_options(display_expand_data=False)
np.set_printoptions(precision=2, suppress=True, edgeitems=1)

# %% [markdown]
# # Opening Best

# %%
ROOT_DIR = '/g/data/w40/ab2313/PhD/time_of_emergence'

os.listdir(os.path.join(ROOT_DIR, 'best'))

# %%
best_ds = xr.open_dataset(os.path.join(ROOT_DIR, 'best', 'Land_and_Ocean_LatLong1.zarr'), 
                    chunks={'time':-1, 'latitude': 90, 'longitude': 120},
                    use_cftime=True)['temperature']

best_ds = best_ds.rename({'latitude':'lat', 'longitude': 'lon'})
best_ds['time'] = xr.cftime_range(start='1850-01-01', freq='M', periods=len(best_ds.time.values))
best_ds = best_ds.resample(time='Y').mean()

# %%
# Only 43MB - load into memory
# best_ds = best_ds.compute()

# %%
best_ds.isel(time=[0, 30, 100]).plot(col='time')

# %%
# Create a data set for the base period used as the pre-industrial climate 
start_end_tuple = (1850, 1900)#(1900, 1931)

base_period_ds = best_ds.where(best_ds.time.dt.year.isin(np.arange(*start_end_tuple)), drop=True)
base_period_ds

# %%
base_period_ds_count = base_period_ds.count(dim='time')

# %%
data_availability_levels = np.arange(0, 61, 10)
data_availability_levels

# %%
base_period_ds_count.plot(levels=data_availability_levels)

# %%
data_availability_mask = xr.where(base_period_ds_count>40, 1, 0)
data_availability_mask

# %%
data_availability_mask.plot()

# %%
best_ds = best_ds.where(data_availability_mask)

# %%
base_period_ds = base_period_ds.where(data_availability_mask)

# %% [markdown]
# # Calculations

# %%
window = 20

# %%
def return_ttest_pvalue(test_arr, base_arr):
    """
    Compute T-Test p-value between two arrays.

    Parameters:
        test_arr (ArrayLike): Array to test against base_arr.
        base_arr (ArrayLike): Base array to compare against.

    Returns:
        float: T-Test p-value.
    """
    return ttest_ind(test_arr, base_arr).pvalue

# %%
def stats_test_1d_array(arr: ArrayLike, window: int, base_period_length:int=50) -> ArrayLike:
    """
    Apply Kolmogorov-Smirnov test along a 1D array.

    Parameters:
        arr (ArrayLike): 1D array to apply the test to.
        window (int): Size of the rolling window for the test.
        base_period_length (int, optional): Length of the base period. Defaults to 50.

    Returns:
        ArrayLike: Array of p-values.
    """
    #print(arr)
    # The data to use for the base period
    base_list = arr[:base_period_length]
    # Fill function with base data - this needs to be done each time as the base period is unique
    stats_test_partial = partial(return_ttest_pvalue, base_arr=base_list) #statstest
    # Stop when there are not enough points left
    
    number_iterations = arr.shape[0] - window
    kstest_array = np.zeros(number_iterations)
    for t in np.arange(number_iterations):
        arr_subset = arr[t:t+window]
        ks_value = stats_test_partial(arr_subset)#.pvalue
        kstest_array[t] = ks_value
    return kstest_array

# %%
subset_kwargs = dict(lat=slice(30,60), lon=slice(30,60))
# chunks = {'time':-1, 'lat':10}

# %%
best_ds_subset = best_ds.isel(**subset_kwargs)#.chunk(chunks)#.data

# %%
best_ds_subset

# %%
CHUNKS_FOR_PVALUE_TESTS =  {'lat':1, 'lon':1, 'time':-1}

# %%
best_ds_subset_window = best_ds_subset.chunk(CHUNKS_FOR_PVALUE_TESTS).rolling(time=window).construct('window_dim')[(window-1):]

# %%
best_ds_subset_window
# Out:
# <xarray.DataArray 'temperature' (time: 156, lat: 30, lon: 30, window_dim: 20)>
# dask.array<chunksize=(156, 1, 1, 20), meta=np.ndarray>
# Coordinates:
#   * lat      (lat) float32 -59.5 -58.5 -57.5 -56.5 ... -33.5 -32.5 -31.5 -30.5
#   * lon      (lon) float32 -149.5 -148.5 -147.5 -146.5 ... -122.5 -121.5 -120.5
#   * time     (time) object 1869-12-31 00:00:00 ... 2024-12-31 00:00:00
# Dimensions without coordinates: window_dim
# Attributes: (5)

# %%
base_period_subset_ds = base_period_ds.chunk(CHUNKS_FOR_PVALUE_TESTS).isel(**subset_kwargs).rename({'time':'window_dim'})

# %%
# Test this
base_period_subset_ds = base_period_subset_ds.persist()

best_ds_subset_window = best_ds_subset_window.persist()

# %%
output_da = xr.apply_ufunc(
        return_ttest_pvalue,
        best_ds_subset_window,
        base_period_subset_ds,
        input_core_dims=[['window_dim'], ['window_dim']],
        exclude_dims={'window_dim'},
        vectorize=True,
        dask='parallelized'#''
    )

# %%
# dask.visualize(output_da.data, rankdir="LR")

# %%
# %%time
output_da = output_da.compute()
# Out:
# CPU times: user 6.74 s, sys: 541 ms, total: 7.28 s
# Wall time: 9 s
# - Connection to tcp://127.0.0.1:56284 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:39137', name: 4, status: running, memory: 24, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.0029752')
# - Connection to tcp://127.0.0.1:56138 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:44387', name: 11, status: running, memory: 26, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.025012')
# - Connection to tcp://127.0.0.1:56192 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:32941', name: 26, status: running, memory: 30, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.0372849')
# - Connection to tcp://127.0.0.1:56260 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:32783', name: 25, status: running, memory: 63, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.0651858')
# - Connection to tcp://127.0.0.1:56124 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:34157', name: 0, status: running, memory: 25, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.0753515')
# - Connection to tcp://127.0.0.1:56144 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:43877', name: 24, status: running, memory: 19, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.0961702')
# - Connection to tcp://127.0.0.1:56140 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:36773', name: 14, status: running, memory: 33, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.1090248')
# - Connection to tcp://127.0.0.1:56190 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:42689', name: 21, status: running, memory: 26, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.1261697')
# - Connection to tcp://127.0.0.1:56268 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:46391', name: 7, status: running, memory: 32, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.1390345')
# - Connection to tcp://127.0.0.1:56236 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:35479', name: 10, status: running, memory: 28, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.1486773')
# - Connection to tcp://127.0.0.1:56176 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:37581', name: 12, status: running, memory: 26, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.1586237')
# - Connection to tcp://127.0.0.1:56228 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:40035', name: 19, status: running, memory: 62, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.170095')
# - Connection to tcp://127.0.0.1:56296 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:44857', name: 5, status: running, memory: 30, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.1835394')
# - Connection to tcp://127.0.0.1:56166 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:35355', name: 22, status: running, memory: 28, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.1887512')
# - Connection to tcp://127.0.0.1:56212 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:46697', name: 23, status: running, memory: 30, processing: 1> (stimulus_id='handle-worker-cleanup-1710742308.1950727')
# - Connection to tcp://127.0.0.1:56098 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:45443', name: 18, status: running, memory: 37, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.2020307')
# - Connection to tcp://127.0.0.1:56160 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:33089', name: 20, status: running, memory: 61, processing: 1> (stimulus_id='handle-worker-cleanup-1710742308.2085924')
# - Connection to tcp://127.0.0.1:56256 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:42815', name: 17, status: running, memory: 20, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.2144573')
# - Connection to tcp://127.0.0.1:56116 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:46275', name: 27, status: running, memory: 31, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.2189345')
# - Connection to tcp://127.0.0.1:56198 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:41031', name: 8, status: running, memory: 34, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.224814')
# - Connection to tcp://127.0.0.1:56248 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:38841', name: 9, status: running, memory: 67, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.2303748')
# - Connection to tcp://127.0.0.1:56164 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:34983', name: 2, status: running, memory: 36, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.236667')
# - Connection to tcp://127.0.0.1:56234 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:38287', name: 15, status: running, memory: 33, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.2416236')
# - Connection to tcp://127.0.0.1:56104 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:42151', name: 13, status: running, memory: 51, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.2462664')
# - Connection to tcp://127.0.0.1:56226 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:38107', name: 16, status: running, memory: 37, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.2524261')
# - Connection to tcp://127.0.0.1:56312 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:36517', name: 3, status: running, memory: 80, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.2576656')
# - Connection to tcp://127.0.0.1:56134 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:42019', name: 6, status: running, memory: 33, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.264342')
# - Connection to tcp://127.0.0.1:56318 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:42213', name: 1, status: running, memory: 33, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.2814672')
# - Worker process 1603916 was killed by signal 15
# - Worker process 1603943 was killed by signal 15
# - Worker process 1603912 was killed by signal 15
# - Worker process 1603907 was killed by signal 15
# - Worker process 1603969 was killed by signal 15
# - Worker process 1603937 was killed by signal 15
# - Worker process 1603925 was killed by signal 15
# - Worker process 1603948 was killed by signal 15
# - Worker process 1603960 was killed by signal 15
# - Worker process 1603952 was killed by signal 15
# - Worker process 1603997 was killed by signal 15
# - Worker process 1603981 was killed by signal 15
# - Worker process 1603955 was killed by signal 15
# - Worker process 1603972 was killed by signal 15
# - Worker process 1604011 was killed by signal 15
# - Worker process 1603993 was killed by signal 15
# - Worker process 1603931 was killed by signal 15
# - Worker process 1604221 was killed by signal 15
# - Worker process 1604205 was killed by signal 15
# - Worker process 1604250 was killed by signal 15
# - Worker process 1604225 was killed by signal 15
# - Worker process 1603921 was killed by signal 15
# - Worker process 1604189 was killed by signal 15
# - Worker process 1604218 was killed by signal 15
# - Worker process 1604271 was killed by signal 15
# - Worker process 1604209 was killed by signal 15
# - Worker process 1604214 was killed by signal 15
# - Worker process 1603985 was killed by signal 15
# - Worker process 1603964 was killed by signal 15
# - Worker process 1603989 was killed by signal 15
# - Worker process 1604015 was killed by signal 15
# - Worker process 1604265 was killed by signal 15
# - Worker process 1604261 was killed by signal 15
# - Worker process 1603977 was killed by signal 15
# - Worker process 1604234 was killed by signal 15
# - Worker process 1604005 was killed by signal 15
# - Worker process 1604258 was killed by signal 15
# - Worker process 1604269 was killed by signal 15
# - Worker process 1604196 was killed by signal 15
# - Worker process 1604253 was killed by signal 15
# - Worker process 1604241 was killed by signal 15
# - Worker process 1603939 was killed by signal 15
# - Worker process 1604000 was killed by signal 15
# - Worker process 1604200 was killed by signal 15
# - Worker process 1604193 was killed by signal 15
# - Worker process 1604237 was killed by signal 15
# - Worker process 1604009 was killed by signal 15
# - Worker process 1604227 was killed by signal 15
# - Worker process 1603926 was killed by signal 15
# - Worker process 1604245 was killed by signal 15
# - Connection to tcp://127.0.0.1:40052 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:39865', name: 35, status: running, memory: 26, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.4749992')
# - Connection to tcp://127.0.0.1:40066 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:46527', name: 32, status: running, memory: 30, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.479393')
# - Connection to tcp://127.0.0.1:40132 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:45059', name: 43, status: running, memory: 31, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.484459')
# - Connection to tcp://127.0.0.1:40110 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:34847', name: 37, status: running, memory: 34, processing: 1> (stimulus_id='handle-worker-cleanup-1710742308.490108')
# - Connection to tcp://127.0.0.1:40034 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:42065', name: 28, status: running, memory: 28, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.495804')
# - Connection to tcp://127.0.0.1:40070 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:45735', name: 36, status: running, memory: 49, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.500429')
# - Connection to tcp://127.0.0.1:40144 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:40801', name: 49, status: running, memory: 78, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.5050485')
# - Connection to tcp://127.0.0.1:40074 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:46143', name: 34, status: running, memory: 24, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.5128496')
# - Connection to tcp://127.0.0.1:40064 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:40865', name: 33, status: running, memory: 34, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.5168827')
# - Connection to tcp://127.0.0.1:40174 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:36019', name: 47, status: running, memory: 34, processing: 1> (stimulus_id='handle-worker-cleanup-1710742308.5218496')
# - Connection to tcp://127.0.0.1:40190 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:39929', name: 46, status: running, memory: 80, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.5265808')
# - Connection to tcp://127.0.0.1:40158 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:40861', name: 45, status: running, memory: 25, processing: 1> (stimulus_id='handle-worker-cleanup-1710742308.5329568')
# - Connection to tcp://127.0.0.1:40128 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:37783', name: 39, status: running, memory: 35, processing: 1> (stimulus_id='handle-worker-cleanup-1710742308.5371776')
# - Connection to tcp://127.0.0.1:40150 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:38357', name: 48, status: running, memory: 34, processing: 1> (stimulus_id='handle-worker-cleanup-1710742308.542555')
# - Connection to tcp://127.0.0.1:40136 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:43325', name: 44, status: running, memory: 22, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.54697')
# - Connection to tcp://127.0.0.1:40062 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:44693', name: 30, status: running, memory: 29, processing: 1> (stimulus_id='handle-worker-cleanup-1710742308.550838')
# - Connection to tcp://127.0.0.1:40106 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:42823', name: 41, status: running, memory: 27, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.5554006')
# - Connection to tcp://127.0.0.1:40048 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:46761', name: 31, status: running, memory: 27, processing: 1> (stimulus_id='handle-worker-cleanup-1710742308.5595589')
# - Task original-open_dataset-temperature-90629226b8cda070b5c14d0c8b407cd7 marked as failed because 4 workers died while trying to run it
# - Connection to tcp://127.0.0.1:40118 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:33231', name: 42, status: running, memory: 27, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.7296097')
# - Connection to tcp://127.0.0.1:40038 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:35915', name: 29, status: running, memory: 21, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.732988')
# - Connection to tcp://127.0.0.1:40100 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:45633', name: 40, status: running, memory: 37, processing: 1> (stimulus_id='handle-worker-cleanup-1710742308.7361243')
# - Task ('array-c1fed3276f8bf5512294ccb688184ae6',) marked as failed because 4 workers died while trying to run it
# - Connection to tcp://127.0.0.1:40084 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:41701', name: 38, status: running, memory: 33, processing: 0> (stimulus_id='handle-worker-cleanup-1710742308.7952094')
# - Lost all workers
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40110>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40110>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40150>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40150>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40118>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40118>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40038>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40038>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40174>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40174>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40128>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40128>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40052>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40052>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40190>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40190>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40144>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40144>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40158>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40158>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40064>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40064>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40084>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40084>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40034>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40034>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40106>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40106>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40136>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40136>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40062>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40062>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40132>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40132>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40100>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40100>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40070>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40070>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40074>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40074>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40066>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40066>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40048>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:35659 remote=tcp://127.0.0.1:40048>: Stream is closed
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Worker process 1604551 was killed by signal 15
# - Worker process 1604560 was killed by signal 15
# - Worker process 1604556 was killed by signal 15
# - Worker process 1604573 was killed by signal 15
# - Worker process 1604548 was killed by signal 15
# - Worker process 1604565 was killed by signal 15
# - Worker process 1604625 was killed by signal 15
# - Worker process 1604652 was killed by signal 15
# - Worker process 1604673 was killed by signal 15
# - Worker process 1604661 was killed by signal 15
# - Worker process 1604669 was killed by signal 15
# - Worker process 1604583 was killed by signal 15
# - Worker process 1604628 was killed by signal 15
# - Worker process 1604579 was killed by signal 15
# - Worker process 1604575 was killed by signal 15
# - Worker process 1604620 was killed by signal 15
# - Worker process 1604609 was killed by signal 15
# - Worker process 1604593 was killed by signal 15
# - Worker process 1604712 was killed by signal 15
# - Worker process 1604741 was killed by signal 15
# - Worker process 1604601 was killed by signal 15
# - Worker process 1604587 was killed by signal 15
# - Worker process 1604617 was killed by signal 15
# - Worker process 1604720 was killed by signal 15
# - Worker process 1604705 was killed by signal 15
# - Worker process 1604700 was killed by signal 15
# - Worker process 1604728 was killed by signal 15
# - Worker process 1604570 was killed by signal 15
# - Worker process 1604676 was killed by signal 15
# - Worker process 1604725 was killed by signal 15
# - Worker process 1604640 was killed by signal 15
# - Worker process 1604690 was killed by signal 15
# - Worker process 1604645 was killed by signal 15
# - Worker process 1604657 was killed by signal 15
# - Worker process 1604709 was killed by signal 15
# - Worker process 1604596 was killed by signal 15
# - Worker process 1604733 was killed by signal 15
# - Worker process 1604637 was killed by signal 15
# - Worker process 1604633 was killed by signal 15
# - Worker process 1604664 was killed by signal 15
# - Worker process 1604647 was killed by signal 15
# - Worker process 1604605 was killed by signal 15
# - Worker process 1604717 was killed by signal 15
# - Worker process 1604613 was killed by signal 15
# - Worker process 1604697 was killed by signal 15
# - Worker process 1604681 was killed by signal 15
# - Worker process 1604693 was killed by signal 15
# - Worker process 1604737 was killed by signal 15
# - Worker process 1604684 was killed by signal 15
# - Worker process 1604743 was killed by signal 15
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker

# %%
best_ds.lat.shape[0] * best_ds.lon.shape[0]
# Out:
# 64800

# %%
# Time takes x scale up factor/ minuts in hour
 #14.8 - when using 16 workers, but no chunk change
# 17 -  when using default worked and 
time_taken = 6.51
time_taken* 72/60
# Out:
# 7.811999999999999

# %%
64800/900
# Out:
# 72.0
# - Connection to tcp://127.0.0.1:46198 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:41553', name: 24, status: running, memory: 1, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.7383204')
# - Connection to tcp://127.0.0.1:46444 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:35933', name: 14, status: running, memory: 1, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.7521448')
# - Connection to tcp://127.0.0.1:46324 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:42377', name: 21, status: running, memory: 39, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.7551737')
# - Connection to tcp://127.0.0.1:46358 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:38863', name: 7, status: running, memory: 1, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.760002')
# - Connection to tcp://127.0.0.1:46390 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:46121', name: 26, status: running, memory: 1, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.7626452')
# - Connection to tcp://127.0.0.1:46456 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:44379', name: 25, status: running, memory: 1, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.7653902')
# - Connection to tcp://127.0.0.1:46406 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:37815', name: 9, status: running, memory: 1, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.7677686')
# - Connection to tcp://127.0.0.1:46304 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:43877', name: 16, status: running, memory: 1, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.7711477')
# - Connection to tcp://127.0.0.1:46356 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:44035', name: 12, status: running, memory: 1, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.77406')
# - Connection to tcp://127.0.0.1:46378 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:37333', name: 27, status: running, memory: 1, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.7768052')
# - Connection to tcp://127.0.0.1:46274 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:39057', name: 8, status: running, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.7799141')
# - Connection to tcp://127.0.0.1:46430 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:40613', name: 13, status: running, memory: 4, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.7849827')
# - Connection to tcp://127.0.0.1:46448 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:35329', name: 20, status: running, memory: 1, processing: 1> (stimulus_id='handle-worker-cleanup-1710741774.7879703')
# - Connection to tcp://127.0.0.1:46262 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:42933', name: 23, status: running, memory: 1, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.7915273')
# - Connection to tcp://127.0.0.1:46214 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:40899', name: 15, status: running, memory: 2, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.794353')
# - Connection to tcp://127.0.0.1:46306 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:40637', name: 17, status: running, memory: 1, processing: 1> (stimulus_id='handle-worker-cleanup-1710741774.7974803')
# - Connection to tcp://127.0.0.1:46344 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:43425', name: 5, status: running, memory: 4, processing: 1> (stimulus_id='handle-worker-cleanup-1710741774.801432')
# - Connection to tcp://127.0.0.1:46334 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:38207', name: 4, status: running, memory: 1, processing: 1> (stimulus_id='handle-worker-cleanup-1710741774.8063164')
# - Connection to tcp://127.0.0.1:46314 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:43913', name: 10, status: running, memory: 1, processing: 1> (stimulus_id='handle-worker-cleanup-1710741774.80951')
# - Connection to tcp://127.0.0.1:46246 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:43787', name: 2, status: running, memory: 1, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.8160837')
# - Connection to tcp://127.0.0.1:46298 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:44311', name: 0, status: running, memory: 0, processing: 1> (stimulus_id='handle-worker-cleanup-1710741774.8187153')
# - Connection to tcp://127.0.0.1:46440 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:36255', name: 1, status: running, memory: 2, processing: 1> (stimulus_id='handle-worker-cleanup-1710741774.824089')
# - Task ('array-c1fed3276f8bf5512294ccb688184ae6',) marked as failed because 4 workers died while trying to run it
# - Closing Nanny gracefully at 'tcp://127.0.0.1:37417'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:45903'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:46737'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:34079'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:34009'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:34809'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:34791'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:33329'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:39499'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:38137'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:41171'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:43675'. Reason: worker-close
# - Connection to tcp://127.0.0.1:46286 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:34799', name: 6, status: running, memory: 2, processing: 1> (stimulus_id='handle-worker-cleanup-1710741774.8633807')
# - Connection to tcp://127.0.0.1:46224 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:43541', name: 18, status: running, memory: 1, processing: 1> (stimulus_id='handle-worker-cleanup-1710741774.8671067')
# - Connection to tcp://127.0.0.1:46276 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:33331', name: 19, status: running, memory: 0, processing: 1> (stimulus_id='handle-worker-cleanup-1710741774.8717506')
# - Connection to tcp://127.0.0.1:46418 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:34205', name: 22, status: running, memory: 1, processing: 1> (stimulus_id='handle-worker-cleanup-1710741774.8756628')
# - Connection to tcp://127.0.0.1:46232 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:34147', name: 3, status: running, memory: 1, processing: 2> (stimulus_id='handle-worker-cleanup-1710741774.8807385')
# - Task ('array-04d12c93f790156507fa2f08a3da69f4', 0, 0, 0) marked as failed because 4 workers died while trying to run it
# - Task original-open_dataset-temperature-90629226b8cda070b5c14d0c8b407cd7 marked as failed because 4 workers died while trying to run it
# - Connection to tcp://127.0.0.1:46366 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:45517', name: 11, status: running, memory: 1, processing: 0> (stimulus_id='handle-worker-cleanup-1710741774.890787')
# - Lost all workers
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46306>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46344>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46298>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46448>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46276>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46276>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46232>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46232>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46418>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46418>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46286>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46286>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46444>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46440>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46378>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46406>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46334>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46358>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46274>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46430>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46214>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46324>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46262>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46224>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46224>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46246>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46304>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46314>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46356>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46456>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46366>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46366>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40987 remote=tcp://127.0.0.1:46390>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# - Closing Nanny gracefully at 'tcp://127.0.0.1:40783'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:44881'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:36939'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:38405'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:45355'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:35855'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:44639'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:44517'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:33521'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:43611'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:45445'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:36933'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:46795'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:35541'. Reason: worker-handle-scheduler-connection-broken
# - Closing Nanny gracefully at 'tcp://127.0.0.1:37027'. Reason: worker-close
# - Closing Nanny gracefully at 'tcp://127.0.0.1:37703'. Reason: worker-close
# - Received heartbeat from unregistered worker 'tcp://127.0.0.1:42377'.
# - Received heartbeat from unregistered worker 'tcp://127.0.0.1:33331'.
# - Received heartbeat from unregistered worker 'tcp://127.0.0.1:34799'.
# - Received heartbeat from unregistered worker 'tcp://127.0.0.1:41553'.
# - Received heartbeat from unregistered worker 'tcp://127.0.0.1:43787'.
# - Received heartbeat from unregistered worker 'tcp://127.0.0.1:36255'.
# - Received heartbeat from unregistered worker 'tcp://127.0.0.1:45517'.
# - Received heartbeat from unregistered worker 'tcp://127.0.0.1:34205'.
# - Received heartbeat from unregistered worker 'tcp://127.0.0.1:34147'.
# - Worker process 1602015 was killed by signal 15
# - Closing Nanny at 'tcp://127.0.0.1:45355'. Reason: nanny-close-gracefully
# - Worker process 1602048 was killed by signal 15
# - Closing Nanny at 'tcp://127.0.0.1:46737'. Reason: nanny-close-gracefully
# - Worker process 1602044 was killed by signal 15
# - Worker process 1602023 was killed by signal 15
# - Closing Nanny at 'tcp://127.0.0.1:36939'. Reason: nanny-close-gracefully
# - Closing Nanny at 'tcp://127.0.0.1:38405'. Reason: nanny-close-gracefully
# - Worker process 1602019 was killed by signal 15
# - Worker process 1602095 was killed by signal 15
# - Closing Nanny at 'tcp://127.0.0.1:33521'. Reason: nanny-close-gracefully
# - Worker process 1602120 was killed by signal 15
# - Closing Nanny at 'tcp://127.0.0.1:38137'. Reason: nanny-close-gracefully
# - Worker process 1602055 was killed by signal 15
# - Closing Nanny at 'tcp://127.0.0.1:43611'. Reason: nanny-close-gracefully
# - Closing Nanny at 'tcp://127.0.0.1:40783'. Reason: nanny-close-gracefully
# - Worker process 1602027 was killed by signal 15
# - Closing Nanny at 'tcp://127.0.0.1:37027'. Reason: nanny-close-gracefully
# - Worker process 1602031 was killed by signal 15
# - Closing Nanny at 'tcp://127.0.0.1:44639'. Reason: nanny-close-gracefully
# - Worker process 1602059 was killed by signal 15
# - Worker process 1602122 was killed by signal 15
# - Closing Nanny at 'tcp://127.0.0.1:37703'. Reason: nanny-close-gracefully
# - Closing Nanny at 'tcp://127.0.0.1:34009'. Reason: nanny-close-gracefully
# - Worker process 1602040 was killed by signal 15
# - Closing Nanny at 'tcp://127.0.0.1:35855'. Reason: nanny-close-gracefully
# - Worker process 1602063 was killed by signal 15
# - Worker process 1602035 was killed by signal 15
# 2024-03-18 17:02:54,956 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:46584 remote=tcp://127.0.0.1:40987>: Stream is closed
# 2024-03-18 17:02:54,957 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:46560 remote=tcp://127.0.0.1:40987>: Stream is closed
# 2024-03-18 17:02:54,957 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:46596 remote=tcp://127.0.0.1:40987>: Stream is closed
# 2024-03-18 17:02:54,967 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:46598 remote=tcp://127.0.0.1:40987>: Stream is closed
# 2024-03-18 17:02:54,970 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:46546 remote=tcp://127.0.0.1:40987>: Stream is closed
# 2024-03-18 17:02:54,976 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:46632 remote=tcp://127.0.0.1:40987>: Stream is closed
# 2024-03-18 17:02:54,976 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:46510 remote=tcp://127.0.0.1:40987>: Stream is closed
# 2024-03-18 17:02:54,986 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:46644 remote=tcp://127.0.0.1:40987>: Stream is closed
# 2024-03-18 17:02:54,989 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:46616 remote=tcp://127.0.0.1:40987>: Stream is closed
# - Closing Nanny at 'tcp://127.0.0.1:34809'. Reason: nanny-close-gracefully
# - Closing Nanny at 'tcp://127.0.0.1:41171'. Reason: nanny-close-gracefully
# - Worker process 1602107 was killed by signal 15
# - Worker process 1602052 was killed by signal 15
# - Worker process 1602087 was killed by signal 15
# - Worker process 1602092 was killed by signal 15
# - Worker process 1602072 was killed by signal 15
# - Worker process 1602115 was killed by signal 15
# - Worker process 1602081 was killed by signal 15
# - Worker process 1602066 was killed by signal 15
# - Closing Nanny at 'tcp://127.0.0.1:39499'. Reason: nanny-close-gracefully
# - Worker process 1602112 was killed by signal 15
# - Worker process 1602102 was killed by signal 15
# - Worker process 1602085 was killed by signal 15
# - Worker process 1602099 was killed by signal 15
# - Closing Nanny at 'tcp://127.0.0.1:45903'. Reason: nanny-close-gracefully
# - Worker process 1602076 was killed by signal 15
# - Closing Nanny at 'tcp://127.0.0.1:36933'. Reason: nanny-close-gracefully
# - Closing Nanny at 'tcp://127.0.0.1:45445'. Reason: nanny-close-gracefully
# - Closing Nanny at 'tcp://127.0.0.1:37417'. Reason: nanny-close-gracefully
# - Closing Nanny at 'tcp://127.0.0.1:44517'. Reason: nanny-close-gracefully
# - Closing Nanny at 'tcp://127.0.0.1:34079'. Reason: nanny-close-gracefully
# - Closing Nanny at 'tcp://127.0.0.1:34791'. Reason: nanny-close-gracefully
# - Closing Nanny at 'tcp://127.0.0.1:44881'. Reason: nanny-close-gracefully
# - Closing Nanny at 'tcp://127.0.0.1:46795'. Reason: nanny-close-gracefully
# - Closing Nanny at 'tcp://127.0.0.1:33329'. Reason: nanny-close-gracefully
# - Closing Nanny at 'tcp://127.0.0.1:35541'. Reason: nanny-close-gracefully
# - Closing Nanny at 'tcp://127.0.0.1:43675'. Reason: nanny-close-gracefully

# %%
# stats_test_1d_array_partial = partial(
#     stats_test_1d_array, 
#     window=20,
#     base_period_length=50
# )

# %%
# %%time
# out_array = np.apply_along_axis(
#     stats_test_1d_array_partial,
#     best_ds.get_axis_num('time'),
#     best_ds_subset.values # fails with data
# )

# %%
# out_array.shape

# %%
# dask.array.apply_along_axis

# %%
# %%time
# out_array = dask.array.apply_along_axis(
#     stats_test_1d_array_partial,
#     best_ds.get_axis_num('time'),
#     best_ds.isel(**subset_kwargs).chunk(chunks).values
# )

# %%
# best_ds_subset_compute = best_ds_subset.compute()

# %%
# base_period_ds_compute = base_period_ds.isel(**subset_kwargs).compute()

# %%
# %%time
# xr.apply_ufunc(
#         return_ttest_pvalue,
#         best_ds_subset_compute.rolling(time=window).construct('window_dim')[(window-1):],
#         base_period_ds_compute.rename({'time':'window_dim'}),
#         input_core_dims=[['window_dim'], ['window_dim']],
#         exclude_dims={'window_dim'},
#         vectorize=True,
#         dask='parallelized'#''
#     )

# %%
# %%time
# xr.apply_ufunc(
#         return_ttest_pvalue,
#         best_ds_subset.rolling(time=window).construct('window_dim')[(window-1):],
#         base_period_ds.isel(**subset_kwargs).rename({'time':'window_dim'}),
#         input_core_dims=[['window_dim'], ['window_dim']],
#         exclude_dims={'window_dim'},
#         vectorize=True,
#         dask='parallelized'#''
#     ).compute()
