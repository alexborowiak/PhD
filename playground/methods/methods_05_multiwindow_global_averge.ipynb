# %% [markdown]
# # Methods of De-treding
# This notebook outllines different methods that can be used to de-trend the LongRunMIP and ZECMIP time series.

# %%
import nc_time_axis
import warnings

import xarray as xr
import numpy as np
import pandas as pd
from importlib import reload
import string

from scipy.stats import spearmanr
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec 


import os
import sys

from numpy.typing import ArrayLike
from typing import Optional, Callable, List, Tuple, Dict

warnings.filterwarnings('ignore')

import constants
from constants import PlotConfig
sys.path.append(constants.MODULE_DIR)
import sn_plotting
import xarray_class_accessors as xca
import utils
import stats
import xarray_extender as xce
import signal_to_noise as sn
import open_ds
from classes import ExperimentTypes, LocationsLatLon
import plotting_functions
logger = utils.get_notebook_logger()

# %%
notebook_number='05'

# %%
import dask.distributed as dd
import tempfile

tempdir = tempfile.TemporaryDirectory("dask-worker-space")
dd.Client(local_directory=tempdir.name, memory_limit='16gb')
# Out:
# <Client: 'tcp://127.0.0.1:44563' processes=4 threads=16, memory=59.60 GiB>

# %% [markdown]
# # Loading Data

# %%
experiment_params = constants.EXPERIMENTS_TO_RUN[0]

# %%
control_abrupt_da = open_ds.open_experiment_files(experiment_params, ExperimentTypes.CONTROL)
abrupt4x_da = open_ds.open_experiment_files(experiment_params, ExperimentTypes.ABRUPT4X)
# Out:
# - Opening control
# - ['ccsm3' 'cesm104' 'cnrmcm61' 'hadcm3l' 'ipslcm5a' 'mpiesm11' 'mpiesm12']=
# - /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped=
# - Opening files in /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped
# - --- Running function 'read_longrunmip_netcdf'
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_CCSM3_control_1530_g025.nc
# - --- Running function 'read_longrunmip_netcdf'
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_CESM104_control_1000_g025.nc
# - --- Running function 'read_longrunmip_netcdf'
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_CNRMCM61_control_2000_g025.nc
# - --- Running function 'read_longrunmip_netcdf'
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_HadCM3L_control_1000_g025.nc
# - --- Running function 'read_longrunmip_netcdf'
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_IPSLCM5A_control_1000_g025.nc
# - --- Running function 'read_longrunmip_netcdf'
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_ann_MPIESM11_control_2000_g025.nc
# - --- Running function 'read_longrunmip_netcdf'
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_MPIESM12_control_1237_g025.nc
# - Time length with all models present 1000
# - Length of final dataset 1000
# Dataset has coords ['time', 'lon', 'lat', 'height'])
# Dataset has data vars ['ccsm3', 'cesm104', 'cnrmcm61', 'hadcm3l', 'ipslcm5a', 'mpiesm11', 'mpiesm12']
# - Converted to datarray with new_coord_name='model' and name
#
#
# - Opening abrupt4x
# - ['ccsm3' 'cesm104' 'cnrmcm61' 'hadcm3l' 'ipslcm5a' 'mpiesm11' 'mpiesm12']=
# - /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped=
# - Opening files in /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped
# - --- Running function 'read_longrunmip_netcdf'
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_CCSM3_abrupt4x_2120_g025.nc
# - --- Running function 'read_longrunmip_netcdf'
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_CESM104_abrupt4x_5900_g025.nc
# - --- Running function 'read_longrunmip_netcdf'
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_CNRMCM61_abrupt4x_1850_g025.nc
# - --- Running function 'read_longrunmip_netcdf'
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_HadCM3L_abrupt4x_1000_g025.nc
# - --- Running function 'read_longrunmip_netcdf'
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_IPSLCM5A_abrupt4x_1000_g025.nc
# - --- Running function 'read_longrunmip_netcdf'
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_ann_MPIESM11_abrupt4x_4459_g025.nc
# - --- Running function 'read_longrunmip_netcdf'
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_MPIESM12_abrupt4x_999_g025.nc
# - Time length with all models present 1000
# - Length of final dataset 1000
# Dataset has coords ['time', 'lon', 'lat', 'height'])
# Dataset has data vars ['ccsm3', 'cesm104', 'cnrmcm61', 'hadcm3l', 'ipslcm5a', 'mpiesm11', 'mpiesm12']
# - Converted to datarray with new_coord_name='model' and name

# %%
abrupt4x_da_smean, control_abrupt_da_smean = sn.calculate_global_value(
    abrupt4x_da, control_abrupt_da, experiment_params["variable"])
# Out:
# (None, None)

# %% [markdown]
# # Local Points

# %% [markdown]
# ## SN

# %%
def doulbe_trend(da, slice1, slice2, **kwargs):

    trend1_da = stats.trend_fit(da.isel(time=slice(*slice1)),**kwargs)
    trend2_da = stats.trend_fit(da.isel(time=slice(*slice2)),**kwargs)

    return trend2_da.combine_first(trend1_da)

# %%
def signal_to_noise_and_save(save_name, *args, **kwargs):
    print(f'Running {save_name}', end='')
    sn_da = sn.signal_to_noise(*args, **kwargs)
    sn_da.to_netcdf(os.path.join(TEST_SAVE_DIR, save_name))
    print(': COMPLETED')

# %%
window = constants.WINDOWS_OF_INTEREST[0]

# %%
TEST_SAVE_DIR = os.path.join(constants.LONGRUNMIP_DIR, experiment_params['variable'], 'method_test')

# %%
for window in constants.WINDOWS_OF_INTEREST[1:]:
    for order in [3,4,5,6]:
        print(f'{window=}, {order=}')
        
        double_trend_da_local = doulbe_trend(abrupt4x_da, (0,100), (100, None),
                                             method='polynomial', order=order)
        detrended_da_local = abrupt4x_da - double_trend_da_local
        
        signal_to_noise_and_save(
            f'abrupt4x_polynomial_static_order_{order}_window_{window}.nc',
            window=window, da=abrupt4x_da,
            da_for_noise=detrended_da_local, rolling_noise=False, time_slice=(0,100))
        
        da_control_no_roll = signal_to_noise_and_save(
            f'control_polynomial_static_order_{order}_window_{window}.nc',
            window=window, da=control_abrupt_da,
            detrend=False, rolling_noise=False)
        
        signal_to_noise_and_save(
              f'abrupt4x_polynomial_rolling_order_{order}_window_{window}.nc', 
            window=window, da=abrupt4x_da,
            da_for_noise=detrended_da_local, rolling_noise=True)
        
        signal_to_noise_and_save(
            f'control_rolling_static_order_{order}_window_{window}.nc', 
            window=window, da=control_abrupt_da,
            detrend=False, rolling_noise=True)
# Out:
# window=80, order=3
# Running abrupt4x_polynomial_static_order_3_window_80.nc80,
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[12], line 9
#       5 double_trend_da_local = doulbe_trend(abrupt4x_da, (0,100), (100, None),
#       6                                      method='polynomial', order=order)
#       7 detrended_da_local = abrupt4x_da - double_trend_da_local
# ----> 9 signal_to_noise_and_save(
#      10     f'abrupt4x_polynomial_static_order_{order}_window_{window}.nc',
#      11     window=window, da=abrupt4x_da,
#      12     da_for_noise=detrended_da_local, rolling_noise=False, time_slice=(0,100))
#      14 da_control_no_roll = signal_to_noise_and_save(
#      15     f'control_polynomial_static_order_{order}_window_{window}.nc',
#      16     window=window, da=control_abrupt_da,
#      17     detrend=False, rolling_noise=False)
#      19 signal_to_noise_and_save(
#      20       f'abrupt4x_polynomial_rolling_order_{order}_window_{window}.nc',
#      21     window=window, da=abrupt4x_da,
#      22     da_for_noise=detrended_da_local, rolling_noise=True)
#
# Cell In[9], line 3, in signal_to_noise_and_save(save_name, *args, **kwargs)
#       1 def signal_to_noise_and_save(save_name, *args, **kwargs):
#       2     print(f'Running {save_name}', end='')
# ----> 3     sn_da = sn.signal_to_noise(*args, **kwargs)
#       4     sn_da.to_netcdf(os.path.join(TEST_SAVE_DIR, save_name))
#       5     print(': COMPLETED')
#
# File ~/Documents/PhD/modules/signal_to_noise.py:204, in signal_to_noise(window, da, da_for_noise, rolling_noise, logginglevel, detrend, detrend_kwargs, time_slice, return_all)
#     201 if logginglevel == 'ERROR': print(f'{window}, ', end='')
#     203 # Signal is always rolling and always the data provided - no static, no detrend etc.
# --> 204 signal_da = da.sn.rolling_signal(window=window)
#     206 da_for_noise = allocate_data_for_noise_calculation(
#     207     da=da, da_for_noise=da_for_noise, detrend_kwargs=detrend_kwargs, detrend=detrend, time_slice=time_slice,
#     208     logginglevel=logginglevel)
#     211 noise_da = noise(da_for_noise=da_for_noise, window=window, rolling_noise=rolling_noise, logginglevel=logginglevel)
#
# File ~/Documents/PhD/modules/xarray_class_accessors.py:209, in SignalToNoise.rolling_signal(self, window, min_periods, logginglevel)
#     207 denominator = np.mean(xs) **2 - np.mean(xs**2)
#     208 mean_xs = np.nanmean(xs)
# --> 209 signal_da = data.rolling(time=window, min_periods=min_periods, center=True).reduce(
#     210     self.__grid_gradient, xs=xs, mean_xs=mean_xs, denominator=denominator) * window
#     212 signal_da = signal_da.sn.adjust_time_from_rolling(window = window, logginglevel=logginglevel)
#     214 signal_da.name = 'signal'
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/xarray/core/rolling.py:478, in DataArrayRolling.reduce(self, func, keep_attrs, **kwargs)
#     473     obj = self.obj
#     474 windows = self._construct(
#     475     obj, rolling_dim, keep_attrs=keep_attrs, fill_value=fillna
#     476 )
# --> 478 result = windows.reduce(
#     479     func, dim=list(rolling_dim.values()), keep_attrs=keep_attrs, **kwargs
#     480 )
#     482 # Find valid windows based on count.
#     483 counts = self._counts(keep_attrs=False)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/xarray/core/dataarray.py:3657, in DataArray.reduce(self, func, dim, axis, keep_attrs, keepdims, **kwargs)
#    3613 def reduce(
#    3614     self: T_DataArray,
#    3615     func: Callable[..., Any],
#    (...)
#    3621     **kwargs: Any,
#    3622 ) -> T_DataArray:
#    3623     """Reduce this array by applying `func` along some dimension(s).
#    3624
#    3625     Parameters
#    (...)
#    3654         summarized data and the indicated dimension(s) removed.
#    3655     """
# -> 3657     var = self.variable.reduce(func, dim, axis, keep_attrs, keepdims, **kwargs)
#    3658     return self._replace_maybe_drop_dims(var)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/xarray/core/variable.py:1947, in Variable.reduce(self, func, dim, axis, keep_attrs, keepdims, **kwargs)
#    1943     if isinstance(axis, tuple) and len(axis) == 1:
#    1944         # unpack axis for the benefit of functions
#    1945         # like np.argmin which can't handle tuple arguments
#    1946         axis = axis[0]
# -> 1947     data = func(self.data, axis=axis, **kwargs)
#    1948 else:
#    1949     data = func(self.data, **kwargs)
#
# File ~/Documents/PhD/modules/xarray_class_accessors.py:161, in SignalToNoise.__grid_gradient(arr, axis, xs, mean_xs, denominator)
#     158 if denominator is None: denominator = np.mean(xs) **2 - np.mean(xs**2)
#     159 if mean_xs is None: mean_xs = np.nanmean(xs)
# --> 161 xs_mult_arr = np.apply_along_axis(__mult_func, axis=axis, arr=arr, arr2=xs)
#     163 t1 = mean_xs * np.nanmean(arr, axis=axis)
#     164 t2 = np.nanmean(xs_mult_arr, axis=axis)
#
# File <__array_function__ internals>:180, in apply_along_axis(*args, **kwargs)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/numpy/lib/shape_base.py:385, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     379 res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     381 # build a buffer for storing evaluations of func1d.
#     382 # remove the requested axis, and add the new ones on the end.
#     383 # laid out so that each write is contiguous.
#     384 # for a tuple index inds, buff[inds] = func1d(inarr_view[inds])
# --> 385 buff = zeros(inarr_view.shape[:-1] + res.shape, res.dtype)
#     387 # permutation of axes such that out = buff.transpose(buff_permute)
#     388 buff_dims = list(range(buff.ndim))
#
# MemoryError: Unable to allocate 43.3 GiB for an array with shape (7, 1000, 72, 144, 80) and data type float64

# %% [markdown]
# ## SN and Bounds

# %%
sn_local_multi_static_ds = sn.multiwindow_signal_to_nosie_and_bounds(
    abrupt4x_da.chunk(constants.LONGRUNMIP_CHUNKS),
    control_abrupt_da.chunk(constants.LONGRUNMIP_CHUNKS),
    da_for_noise = detrended_da_local.chunk(constants.LONGRUNMIP_CHUNKS),
    logginglevel='INFO', parallel=False, rolling_noise=False, time_slice=(0, 100),
    windows=constants.WINDOWS_OF_INTEREST[:0])
# Out:
# - sn_kwargs={'windows': [], 'start_window': 21, 'end_window': None, 'step_window': None, 'rolling_noise': False, 'parallel': False, 'time_slice': (0, 100), 'logginglevel': 'INFO'}
#
# Experiment
# --------
# - windows=[21]
# - -- allocate_data_for_noise_calculation
# - Dataset for nosie provided
# - slicing time with integers (0, 100)
# 21, - Calculting the rolling signal
# - rolling_noise=False
#  - Finished
#
# Control
# ------
#
# - windows=[21]
# - -- allocate_data_for_noise_calculation
# - Dataset for nosie provided
# - slicing time with integers (0, 100)
# 21, - Calculting the rolling signal
# - rolling_noise=False
# Calculating bounds
# - Calculating Upper and lower control bounds
# - Map blocks used
# final merge

# %%
window = 21

# %%
sn_local_multi_static_ds = sn_local_multi_static_ds.compute()
# Out:
# 2023-03-06 16:10:35,085 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 9.44 GiB -- Worker memory limit: 14.90 GiB
# Exception ignored in: <bound method GCDiagnosis._gc_callback of <distributed.utils_perf.GCDiagnosis object at 0x7fd11b393520>>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/utils_perf.py", line 179, in _gc_callback
#     def _gc_callback(self, phase, info):
# KeyboardInterrupt:
# Exception ignored in: <bound method GCDiagnosis._gc_callback of <distributed.utils_perf.GCDiagnosis object at 0x7fd11b393520>>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/utils_perf.py", line 179, in _gc_callback
#     def _gc_callback(self, phase, info):
# KeyboardInterrupt:
# Exception ignored in: <function WeakSet.__init__.<locals>._remove at 0x7fd11b1a3670>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/_weakrefset.py", line 39, in _remove
#     def _remove(item, selfref=ref(self)):
# KeyboardInterrupt:
# - Task exception was never retrieved
# future: <Task finished name='Task-1895486' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895487' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895488' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895489' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895490' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895491' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895492' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895493' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895494' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895495' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895496' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895497' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895498' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895499' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895500' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895501' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895502' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895503' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895504' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895505' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895506' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895507' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895508' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1895509' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Exception ignored in: <bound method BaseEventLoop.call_exception_handler of <_UnixSelectorEventLoop running=True closed=False debug=False>>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/asyncio/base_events.py", line 1779, in call_exception_handler
#     self.default_exception_handler(context)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/asyncio/base_events.py", line 1753, in default_exception_handler
#     logger.error('\n'.join(log_lines), exc_info=exc_info)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/logging/__init__.py", line 1475, in error
#     self._log(ERROR, msg, args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/logging/__init__.py", line 1589, in _log
#     self.handle(record)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/logging/__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/logging/__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/logging/__init__.py", line 952, in handle
#     self.emit(record)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/logging/__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/logging/__init__.py", line 927, in format
#     return fmt.format(record)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/logging/__init__.py", line 671, in format
#     record.exc_text = self.formatException(record.exc_info)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/logging/__init__.py", line 621, in formatException
#     traceback.print_exception(ei[0], ei[1], tb, None, sio)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/traceback.py", line 103, in print_exception
#     for line in TracebackException(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/traceback.py", line 517, in __init__
#     self.stack = StackSummary.extract(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/traceback.py", line 362, in extract
#     linecache.checkcache(filename)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/linecache.py", line 72, in checkcache
#     stat = os.stat(fullname)
# KeyboardInterrupt:
# - Task exception was never retrieved
# future: <Task finished name='Task-1897805' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897806' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897807' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897808' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897809' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897810' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897811' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897812' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897813' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897814' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897815' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897816' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897817' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897818' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897819' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897822' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897823' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897824' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897825' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# - Task exception was never retrieved
# future: <Task finished name='Task-1897826' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# KeyboardInterrupt

# %%
sn_local_multi_static_ds.to_netcdf(os.path.join(TEST_SAVE_DIR, f'static_window_{window}_double_polynomial.nc'))
# Out:
# 2023-03-06 15:28:37,151 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 9.57 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:29:51,192 - distributed.nanny - WARNING - Restarting worker
# 2023-03-06 15:30:07,908 - distributed.nanny - WARNING - Restarting worker
# 2023-03-06 15:30:09,390 - distributed.nanny - WARNING - Worker process still alive after 3.19999740600586 seconds, killing
# 2023-03-06 15:30:12,956 - distributed.nanny - WARNING - Restarting worker
# 2023-03-06 15:30:26,128 - distributed.nanny - WARNING - Worker process still alive after 3.1999980163574224 seconds, killing
# 2023-03-06 15:45:36,218 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 9.81 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:52,666 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.43 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:52,779 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.43 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:52,933 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.43 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:52,972 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.43 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:53,127 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.43 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:53,192 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.43 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:53,264 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:53,405 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:53,576 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:53,715 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:53,885 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:54,039 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:54,092 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:54,205 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:54,275 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:54,396 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:54,476 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:54,579 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:54,720 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:54,775 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:54,885 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:54,973 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:55,059 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:55,199 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:55,261 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:55,403 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:55,462 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:55,568 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:55,677 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:55,766 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:55,878 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:55,986 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:56,079 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:56,162 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:56,281 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:56,397 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:56,482 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:56,602 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:56,678 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:56,762 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.44 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:56,875 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:56,990 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:57,094 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:57,176 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:57,308 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:57,371 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:57,477 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:57,572 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:57,660 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:57,760 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:57,897 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:57,975 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:58,077 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:58,159 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:58,262 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:58,368 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:58,461 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:58,565 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:58,676 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:58,761 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:58,879 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:58,984 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:59,077 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:59,177 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:59,260 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:59,365 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:59,504 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:59,560 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:59,691 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:59,808 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:48:59,997 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:00,080 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:00,166 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:00,262 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.45 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:00,547 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:00,575 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:00,662 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:00,759 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:00,862 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:00,970 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:01,079 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:01,179 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:01,262 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:01,395 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:01,464 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:01,596 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:01,669 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:01,763 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:01,904 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:01,973 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:02,076 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:02,166 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:02,268 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:02,369 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:02,467 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:02,576 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:02,662 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:02,781 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:02,942 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:02,992 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:03,077 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:03,172 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:03,264 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:03,430 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:03,464 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:03,563 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:03,669 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:03,773 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.46 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:04,072 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:04,164 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:04,287 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:04,491 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:04,581 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:04,673 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:04,776 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:04,977 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:05,092 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:05,202 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:05,284 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:05,371 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:05,479 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:05,587 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:05,686 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:05,788 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:05,940 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:05,972 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:06,061 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:06,231 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:06,285 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:06,402 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 15:49:06,505 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 10.47 GiB -- Worker memory limit: 14.90 GiB
# ...
# 2023-03-06 16:00:46,075 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.36 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:46,165 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.39 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:46,272 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:46,377 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:46,461 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:46,563 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:46,660 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:46,783 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.47 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:46,905 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.36 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:46,961 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.41 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:47,077 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.49 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:47,173 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.57 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:47,276 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.66 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:47,358 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.73 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:47,463 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.81 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:47,591 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.91 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:47,849 - distributed.worker_memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 11.97 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:47,849 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.97 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:47,919 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.16 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:47,976 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.19 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:48,069 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.26 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:48,166 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.34 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:48,293 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.41 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:48,425 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.52 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:48,484 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.56 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:48,561 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.64 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:48,677 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.73 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:48,780 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.80 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:48,881 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.86 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:48,961 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.89 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:49,075 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.96 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:49,171 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.96 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:49,268 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.96 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:49,381 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 12.96 GiB -- Worker memory limit: 14.90 GiB
# 2023-03-06 16:00:49,469 - distributed.worker_memory - WARNING - Worker is at 66% memory usage. Resuming worker. Process memory: 9.95 GiB -- Worker memory limit: 14.90 GiB
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/nanny.py", line 981, in _run
#     asyncio.run(run())
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/asyncio/runners.py", line 47, in run
#     _cancel_all_tasks(loop)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/asyncio/runners.py", line 63, in _cancel_all_tasks
#     loop.run_until_complete(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/asyncio/base_events.py", line 634, in run_until_complete
#     self.run_forever()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/asyncio/base_events.py", line 634, in run_until_complete
# Exception ignored in: <bound method GCDiagnosis._gc_callback of <distributed.utils_perf.GCDiagnosis object at 0x7fd11b393520>>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/utils_perf.py", line 179, in _gc_callback
#     self.run_forever()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     def _gc_callback(self, phase, info):
# KeyboardInterrupt:
#     self._run_once()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/compatibility.py", line 161, in _run
#     val = self.callback()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/distributed/system_monitor.py", line 144, in update
#     disk_ioc = psutil.disk_io_counters()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/psutil/__init__.py", line 2064, in disk_io_counters
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/psutil/_pslinux.py", line 1157, in disk_io_counters
#
# KeyboardInterrupt
#
#     if not perdisk and not is_storage_device(name):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-22.07/lib/python3.9/site-packages/psutil/_pslinux.py", line 256, in is_storage_device
