# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pandas as pd
import cartopy.crs as ccrs
import xarray as xr
import statsmodels.api as sm 

lowess = sm.nonparametric.lowess
import plotly.express as px
import os
import sys
sys.path.append('')
import signal_to_noise as sn
from importlib import reload

# %%
 = reload(sn)

# %%
ROOT_DIR = '/g/data/w40/ab2313/longrunmip'

# %%
np.array(os.listdir(ROOT_DIR))
# Out:
# array(['tas_ann_ECHAM5MPIOM_1pct4x_6080.nc',
#        'tas_mon_CCSM3_control_1530.nc', 'tas_mon_MIROC32_control_681.nc',
#        'tas_mon_CCSM3_abrupt4x_2120.nc',
#        'tas_ann_FAMOUS_abrupt4x_3000_g025.nc',
#        'tas_ann_ECHAM5MPIOM_control_100.nc',
#        'tas_mon_MIROC32_abrupt4x_150.nc',
#        'tas_mon_CCSM3_abrupt2x_3000.nc', 'tas_mon_CCSM3_abrupt8x_1450.nc',
#        'tas_mon_MIROC32_1pct4x_2002.nc', 'tas_mon_MIROC32_1pct2x_2003.nc'],
#       dtype='<U36')

# %% [markdown]
# # Functions

# %%
def climatology(hist, start = 1850, end = 1901):

    ### CLIMATOLOGY

    # Getting just the years for climatology. This should be for each pixel, the mean temperature
    # from 1850 to 1900. 
    climatology = hist.where(hist.time.dt.year.isin(np.arange(start,end)), drop = True)\
                        .mean(dim = 'time')

    return climatology


def anomalies(data, hist):

    climatology = climatology(hist)

    data_resampled = data.resample(time = 'Y').mean()
    data_anom = (data_resampled - climatology).chunk({'time':8})


    return data_anom

def space_mean(data):
    
        # Lat weights
        weights = np.cos(np.deg2rad(data.lat))
        weights.name= 'weights'
        
        # Calculating the weighted mean.
        data_wmean = data.weighted(weights).mean(dim = ['lat','lon'])

        return data_wmean

# %% [markdown]
# # Loading Data

# %% [markdown]
# ## Each

# %% [markdown]
# 1% CO2 until 4 x CO2

# %%
kwargs = dict(use_cftime = True,
                     chunks = {'lat':100,'lon':100,'time':100})

# %%
ech1pct = xr.open_dataset(f'{ROOT_DIR}/tas_ann_ECHAM5MPIOM_1pct4x_6080.nc', **kwargs)

# %%
print(f'Dates for 4xCO2 1%:\n--------------------\n{ech1pct.time.values[:5]}\n...\n{ech1pct.time.values[-5:]}')
# Out:
# Dates for 4xCO2 1%:
# --------------------
# [cftime.DatetimeGregorian(2500, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2501, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2502, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2503, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2504, 12, 31, 18, 0, 0, 0)]
# ...
# [cftime.DatetimeGregorian(8575, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(8576, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(8577, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(8578, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(8579, 12, 31, 18, 0, 0, 0)]

# %%
echhist = xr.open_dataset(f'{ROOT_DIR}/tas_ann_ECHAM5MPIOM_control_100.nc', **kwargs)
echhist
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 48, lon: 96, time: 100)
# Coordinates:
#   * lat      (lat) float64 87.16 83.48 79.78 76.07 ... -79.78 -83.48 -87.16
#   * lon      (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2
#   * time     (time) object 2400-12-31 18:00:00 ... 2499-12-31 18:00:00
# Data variables:
#     tas      (time, lat, lon) float32 dask.array<chunksize=(100, 48, 96), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version 1.1.1
#     Conventions:  CF-1.0
#     history:      Thu Apr 14 01:58:24 2016: ncatted -O -a long_name,tas,o,c,N...
#     source:       ECHAM5.4
#     institution:  Max-Planck-Institute for Meteorology
#     CDO:          Climate Data Operators version 1.1.1 (http://www.mpimet.mpg...
#     NCO:          4.0.6

# %%
print(f'Dates for hist:\n--------------------\n{echhist.time.values[:5]}\n...\n{echhist.time.values[-5:]}')
# Out:
# Dates for hist:
# --------------------
# [cftime.DatetimeGregorian(2400, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2401, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2402, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2403, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2404, 12, 31, 18, 0, 0, 0)]
# ...
# [cftime.DatetimeGregorian(2495, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2496, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2497, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2498, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2499, 12, 31, 18, 0, 0, 0)]

# %% [markdown]
# # Anomlaies

# %% [markdown]
# <b> Climatology </b>

# %%
ech_clima = sn.climatology(echhist,
                        start = echhist.time.dt.year.values[0], end = echhist.time.dt.year.values[-1])

# %%
ech_clima.coords
# Out:
# Coordinates:
#   * lat      (lat) float64 87.16 83.48 79.78 76.07 ... -79.78 -83.48 -87.16
#   * lon      (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ech_clima.tas.plot(ax = ax, cmap = 'RdBu_r')
ax.set_title('ECH Climatology')
# Out:
# Text(0.5, 1.0, 'ECH Climatology')

# %%
ech1pct_anom = ech1pct - ech_clima

# %%
ech1pct_smean = sn.space_mean(ech1pct_anom.tas).compute()

# %%
ech1pct_smean
# Out:
# <xarray.DataArray (time: 6080)>
# array([-0.11723272,  0.08847581,  0.0936095 , ..., 11.03103541,
#        10.93372189, 11.07065921])
# Coordinates:
#   * time     (time) object 2500-12-31 18:00:00 ... 8579-12-31 18:00:00

# %%
fig, ax = plt.subplots(figsize = (15,5))

ax.plot(ech1pct_smean.time.values, ech1pct_smean.values)

# %% [markdown]
# # LOESS

# %%
def loess_filter(data, step_size = 10):
    
    
    # Getting the values from the dataarray
    y = data.values
    
    # Removign the nans (this is important as if two dataarrays where together in dataset
    # one might have been longer than the other, leaving a trail of NaNs at the end.)
    idy = np.isfinite(y)
    y = y[idy]
    
    # The equally spaced x-values.
    x =  np.arange(len(y))
    
    
    # The fraction to consider the linear trend of each time.
    frac = step_size/len(y)
    
    #yhat is the loess version of y - this is the final product.
    yhat = lowess(y, x, frac  = frac)
    
    return yhat

# %%
ech1pct_smean_loess = loess_filter(ech1pct_smean, step_size = 50)

# %%
ech1pct_smean_loess.shape
# Out:
# (6080, 2)

# %%
ech1pct_smean_loess_de = ech1pct_smean - ech1pct_smean_loess[:,1]

# %%
ech1pct_smean_loess_de
# Out:
# <xarray.DataArray (time: 6080)>
# array([-0.0098924 ,  0.17202227,  0.15333285, ...,  0.12968052,
#         0.03081484,  0.16615384])
# Coordinates:
#   * time     (time) object 2500-12-31 18:00:00 ... 8579-12-31 18:00:00

# %%
fig = plt.figure(figsize = (15,10))

ax = fig.add_subplot(111)
ax.plot(ech1pct_smean.time.values, ech1pct_smean_loess[:,1], label = 'loess')
ax.plot(ech1pct_smean.time.values, ech1pct_smean.values, label = 'raw', zorder = -1)

ax2 = ax.twinx()
ax2.plot(ech1pct_smean_loess_de.time.values,ech1pct_smean_loess_de.values, zorder = -3, alpha = 0.3)

# %% [markdown]
# # Noise

# %% [markdown]
# ## Stationary Noise

# %%
ech1pct_smean_loess_de
# Out:
# <xarray.DataArray (time: 6080)>
# array([-0.0098924 ,  0.17202227,  0.15333285, ...,  0.12968052,
#         0.03081484,  0.16615384])
# Coordinates:
#   * time     (time) object 2500-12-31 18:00:00 ... 8579-12-31 18:00:00

# %%
ech1pct_noise_stationary = ech1pct_smean_loess_de.std(dim = 'time')
ech1pct_noise_stationary
# Out:
# <xarray.DataArray ()>
# array(0.21208068)

# %% [markdown]
# ## Rolling Noise

# %%
ROLL_PERIOD = 60
MIN_PERIODS = ROLL_PERIOD

# %%
ech1pct_noise_rolling = \
    ech1pct_smean_loess_de.rolling(time = ROLL_PERIOD, min_periods = MIN_PERIODS, center = True).std()

# %%
ech1pct_noise_rolling
# Out:
# <xarray.DataArray (time: 6080)>
# array([nan, nan, nan, ..., nan, nan, nan])
# Coordinates:
#   * time     (time) object 2500-12-31 18:00:00 ... 8579-12-31 18:00:00

# %%
ech1pct_noise_rolling.plot()

# %%
fig = plt.figure(figsize = (10,7))
ax = fig.add_subplot(111)


ax.plot(ech1pct_noise_rolling.time.values, ech1pct_noise_rolling.values, label = 'Rolling Noise')

ax.plot([ech1pct_noise_rolling.time.values[0],ech1pct_noise_rolling.time.values[-1]],
        [ech1pct_noise_stationary.values, ech1pct_noise_stationary.values], label = 'Stationary Nosie')


ax.legend(ncol = 2, fontsize = 15)


ax.set_title('Stationary vs. Rolling Noise', size = 18);
ax.set_ylabel('Standard Deviation of detrend data')
# Out:
# Text(0, 0.5, 'Standard Deviation of detrend data')

# %% [markdown]
# # Signal

# %%
ROLL_PERIOD
# Out:
# 60

# %%
sn = reload(sn)
ech_smean_signal = ech1pct_smean.rolling(time = ROLL_PERIOD, min_periods = MIN_PERIODS, center = True)\
        .reduce(sn.apply_along_helper, func1d = sn.grid_trend) * ROLL_PERIOD

# %%
ech_smean_signal.plot()

# %% [markdown]
# # Signal to Nosie

# %%
ech_smean_signal
# Out:
# <xarray.DataArray (time: 6080)>
# array([nan, nan, nan, ..., nan, nan, nan])
# Coordinates:
#   * time     (time) object 2500-12-31 18:00:00 ... 8579-12-31 18:00:00

# %%
ech1pct_noise_stationary
# Out:
# <xarray.DataArray ()>
# array(0.21208068)

# %%
ech1pct_noise_rolling
# Out:
# <xarray.DataArray (time: 6080)>
# array([nan, nan, nan, ..., nan, nan, nan])
# Coordinates:
#   * time     (time) object 2500-12-31 18:00:00 ... 8579-12-31 18:00:00

# %% [markdown]
# <b> Stationary Noise

# %%
ech1pct_sn_stationary = ech_smean_signal/ech1pct_noise_stationary
ech1pct_sn_stationary
# Out:
# <xarray.DataArray (time: 6080)>
# array([nan, nan, nan, ..., nan, nan, nan])
# Coordinates:
#   * time     (time) object 2500-12-31 18:00:00 ... 8579-12-31 18:00:00

# %%
ech1pct_sn_rolling = ech_smean_signal/ech1pct_noise_rolling
ech1pct_sn_rolling
# Out:
# <xarray.DataArray (time: 6080)>
# array([nan, nan, nan, ..., nan, nan, nan])
# Coordinates:
#   * time     (time) object 2500-12-31 18:00:00 ... 8579-12-31 18:00:00

# %%
UNUSUAL = 2
UNKNOWN = 3

# %%
import matplotlib.ticker as mticker

# %%
fig = plt.figure(figsize=  (15,10))
ax = fig.add_subplot(111)

time =  ech1pct_sn_rolling.time.values

ax.plot(time,ech1pct_sn_rolling, label = 'Rolling', c = 'darkred')
ax.plot(time, ech1pct_sn_stationary, label = 'Stationary', c = 'tomato')
c0 = plt.gca().lines[0].get_color()
ax.tick_params(axis = 'y', labelcolor = c0)
ax.set_ylabel('Signal\n----------\nNoise', fontsize = 12, color = c0, rotation = 0, labelpad = 55);

leg = ax.legend(ncol = 1, fontsize = 12, bbox_to_anchor = [1.16, 1])
leg.set_title('Noise Type')
leg.get_title().set_fontsize('12')

ax.plot([time[0], time[-1]],[UNUSUAL, UNUSUAL], color = 'k', linestyle = ':', alpha = 0.65)
ax.plot([time[0], time[-1]],[UNKNOWN, UNKNOWN], color = 'k', linestyle = ':', alpha = 0.65)

ax.annotate('Unusual/Quasi-stable(?)', xy = (time[-900], UNUSUAL + 0.5), ha = 'left')
ax.annotate('Unknown/Unstable(?)', xy = (time[-900], UNKNOWN + 0.5), ha = 'left')
ax.annotate('Stable', xy = (time[-900], UNKNOWN - 1.5), ha = 'left')

ax.yaxis.set_major_locator(mticker.MultipleLocator(2))
ax.yaxis.set_minor_locator(mticker.MultipleLocator(.5))

# Second y-axis: the temperature anomalies.
ax2 = ax.twinx()

ax2.plot(time, ech1pct_smean.values, color = 'green', alpha = 0.4, label  = 'Temp Anomaly')

c1 = plt.gca().lines[0].get_color()
ax2.tick_params(axis = 'y', labelcolor = c1)
ax2.spines['right'].set_color(c1)
ax2.spines['left'].set_color(c0)
ax2.set_ylabel('Tempearture\nAnomaly', fontsize = 12, color = c1, rotation = 0, labelpad = 55);

ax2.set_xlim([time[0], time[-1]])
ax.set_xlabel('Year', fontsize = 12);

# ax.grid(which = 'major', axis = 'both', linestyle = ':', alpha = 0.5, zorder = -100)

ax.set_title(f'Ech 1%CO2/year to 4xCO2 Signal/Noise ({ROLL_PERIOD}Y Window)', size = 15)

# fig.savefig(f'../../images/PhD/init/4xCO2_1%_ECH_SN_{ROLL_PERIOD}Ywindow.png',
#             bbox_inches = 'tight', dpi = 250)
# Out:
# Text(0.5, 1.0, 'Ech 1%CO2/year to 4xCO2 Signal/Noise (60Y Window)')

# %%
fig = plt.figure(figsize=  (15,10))
ax = fig.add_subplot(111)

time =  ech1pct_sn_rolling.time.values

ax.plot(time,ech1pct_sn_rolling, label = 'S/N', c = 'darkred')
ax.plot(time, ech_smean_signal, label = 'Signal')
ax.plot(time, ech1pct_noise_rolling, label = 'Noise')

ax.legend(ncol = 3, fontsize = 15,  bbox_to_anchor = [0.7,1.1])

# %% [markdown]
# # Ovall Signal to Noise Once CO2 Stabalised

# %%
ech1pct_smean.time.values[:5]
# Out:
# array([cftime.DatetimeGregorian(2500, 12, 31, 18, 0, 0, 0),
#        cftime.DatetimeGregorian(2501, 12, 31, 18, 0, 0, 0),
#        cftime.DatetimeGregorian(2502, 12, 31, 18, 0, 0, 0),
#        cftime.DatetimeGregorian(2503, 12, 31, 18, 0, 0, 0),
#        cftime.DatetimeGregorian(2504, 12, 31, 18, 0, 0, 0)], dtype=object)

# %%
co2_stablised_years = np.arange(3900,10000)

# %%
stabalsied_data = ech1pct_smean.where(ech1pct_smean.time.dt.year.isin(co2_stablised_years), drop = True)

# %%
y_stabalised = stabalsied_data.values
x_stabalised = np.arange(len(y_stabalsied))

# %%
stabalised_grad,stabalised_yint = sn.grid_trend(y_stabalised,use = [0,1])

# %% [markdown]
# This is also the signal.

# %%
stabalised_grad
# Out:
# 8.93392641781763e-05

# %%
stablised_trend = stabalised_grad * x_stabalised +  stabalised_yint

# %%
stabalised_signal = stabalised_grad * len(stablised_trend)

# %%
plt.plot(x_stabalised, y_stabalised, x_stabalised, stablised_trend)

# %% [markdown]
# ## Nosie

# %%
ech1pct_smean_loess_de.plot()

# %%
stabalised_noise = ech1pct_smean_loess_de.where(
    ech1pct_smean_loess_de.time.dt.year.isin(co2_stablised_years), drop = True).std(dim = 'time').values
stabalised_noise
# Out:
# array(0.2192945)

# %% [markdown]
# ## Signal to Nosie

# %%
sn_stabalised = stabalised_signal/stabalised_noise
sn_stabalised
# Out:
# 1.9066039418419165

# %% [markdown]
# ## Plotting

# %%
fig = plt.figure(figsize=  (15,10))
ax = fig.add_subplot(111)

ax.plot(ech1pct_smean.time.values, ech1pct_smean.values)


ax.plot(stabalsied_data.time.values, stabalsied_data.values)
ax.plot(stabalsied_data.time.values, stablised_trend)

ax.annotate('Signal : {:.2}\nNoise : {:.2}\nS/N : {:.2}'.format(stabalised_signal,stabalised_noise,sn_stabalised )
            , size =  15, va = 'top', xy = (0.50,.8), xycoords = 'axes fraction', ha = 'left');

# %% [markdown]
# # Loop Roll

# %% [markdown]
# Testing (again) if the rolling function is doing what is should be doing. Below is a more readable version of a subset of the rolling code.

# %%
grad_array = []
for t in np.arange(2000):
    sub_data = ech1pct_smean.isel(time = slice(t, t + ROLL_PERIOD))
    y = sub_data.values
    x = np.arange(len(y))
    grad = np.polyfit(x,y,1)[0]
    grad_array.append(grad)

# %% [markdown]
# As you can see the values here match the abvoe.

# %%
plt.plot(grad_array)

# %% [markdown]
#  # Looking at Start Points

# %% [markdown]
# The start point is interesting as the signal doens't start at the largest value; it peaks then dips.

# %%
sn = reload(sn)

# %%
ROLL_PERIOD
# Out:
# 60

# %% [markdown]
# In this plot you can see that this is probably right. The plot does increase in gradient in the first few points.

# %%
plt.plot(ech1pct_smean.isel(time = slice(0, ROLL_PERIOD + 150)))

# %%
sub_data = ech1pct_smean.isel(time = slice(0, ROLL_PERIOD))
y = sub_data.values
x = np.arange(len(y))

# %%
igrad,iyint = sn.grid_trend(y,use = [0,1])

# %%
igrad, iyint
# Out:
# (0.028572949104113926, -0.1851025666989371)

# %%
y_trend = igrad * x + iyint

# %%
plt.plot(x,y,x,y_trend)
