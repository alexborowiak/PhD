# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pandas as pd
import cartopy.crs as ccrs
import xarray as xr
import statsmodels.api as sm 

lowess = sm.nonparametric.lowess
import plotly.express as px
import os
import sys
sys.path.append('')
import signal_to_noise as sn
from importlib import reload
import plotly.graph_objects as go

# %%
from scipy.stats import kstest

# %%
sn = reload(sn)

# %%
ROOT_DIR = '/g/data/w40/ab2313/longrunmip'

# %%
np.array(os.listdir(ROOT_DIR))
# Out:
# array(['tas_ann_ECHAM5MPIOM_1pct4x_6080.nc',
#        'tas_mon_CCSM3_control_1530.nc', 'tas_mon_MIROC32_control_681.nc',
#        'tas_mon_CCSM3_abrupt4x_2120.nc',
#        'tas_ann_FAMOUS_abrupt4x_3000_g025.nc',
#        'tas_ann_ECHAM5MPIOM_control_100.nc',
#        'tas_mon_MIROC32_abrupt4x_150.nc',
#        'tas_mon_CCSM3_abrupt2x_3000.nc', 'tas_mon_CCSM3_abrupt8x_1450.nc',
#        'tas_mon_MIROC32_1pct4x_2002.nc', 'tas_mon_MIROC32_1pct2x_2003.nc'],
#       dtype='<U36')

# %% [markdown]
# # Functions

# %%
def climatology(hist, start = 1850, end = 1901):

    ### CLIMATOLOGY

    # Getting just the years for climatology. This should be for each pixel, the mean temperature
    # from 1850 to 1900. 
    climatology = hist.where(hist.time.dt.year.isin(np.arange(start,end)), drop = True)\
                        .mean(dim = 'time')

    return climatology


def anomalies(data, hist):

    climatology = climatology(hist)

    data_resampled = data.resample(time = 'Y').mean()
    data_anom = (data_resampled - climatology).chunk({'time':8})


    return data_anom

def space_mean(data):
    
        # Lat weights
        weights = np.cos(np.deg2rad(data.lat))
        weights.name= 'weights'
        
        # Calculating the weighted mean.
        data_wmean = data.weighted(weights).mean(dim = ['lat','lon'])

        return data_wmean

# %% [markdown]
# # Loading Data

# %% [markdown]
# ## Each

# %% [markdown]
# 1% CO2 until 4 x CO2

# %%
kwargs = dict(use_cftime = True,
                     chunks = {'lat':100,'lon':100,'time':100})

# %%
ech1pct = xr.open_dataset(f'{ROOT_DIR}/tas_ann_ECHAM5MPIOM_1pct4x_6080.nc', **kwargs)

# %%
print(f'Dates for 4xCO2 1%:\n--------------------\n{ech1pct.time.values[:5]}\n...\n{ech1pct.time.values[-5:]}')
# Out:
# Dates for 4xCO2 1%:
# --------------------
# [cftime.DatetimeGregorian(2500, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2501, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2502, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2503, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2504, 12, 31, 18, 0, 0, 0)]
# ...
# [cftime.DatetimeGregorian(8575, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(8576, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(8577, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(8578, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(8579, 12, 31, 18, 0, 0, 0)]

# %%
echhist = xr.open_dataset(f'{ROOT_DIR}/tas_ann_ECHAM5MPIOM_control_100.nc', **kwargs)
echhist
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 48, lon: 96, time: 100)
# Coordinates:
#   * lat      (lat) float64 87.16 83.48 79.78 76.07 ... -79.78 -83.48 -87.16
#   * lon      (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2
#   * time     (time) object 2400-12-31 18:00:00 ... 2499-12-31 18:00:00
# Data variables:
#     tas      (time, lat, lon) float32 dask.array<chunksize=(100, 48, 96), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version 1.1.1
#     Conventions:  CF-1.0
#     history:      Thu Apr 14 01:58:24 2016: ncatted -O -a long_name,tas,o,c,N...
#     source:       ECHAM5.4
#     institution:  Max-Planck-Institute for Meteorology
#     CDO:          Climate Data Operators version 1.1.1 (http://www.mpimet.mpg...
#     NCO:          4.0.6

# %%
print(f'Dates for hist:\n--------------------\n{echhist.time.values[:5]}\n...\n{echhist.time.values[-5:]}')
# Out:
# Dates for hist:
# --------------------
# [cftime.DatetimeGregorian(2400, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2401, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2402, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2403, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2404, 12, 31, 18, 0, 0, 0)]
# ...
# [cftime.DatetimeGregorian(2495, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2496, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2497, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2498, 12, 31, 18, 0, 0, 0)
#  cftime.DatetimeGregorian(2499, 12, 31, 18, 0, 0, 0)]

# %% [markdown]
# # Anomlaies

# %% [markdown]
# <b> Climatology </b>

# %%
ech_clima = sn.climatology(echhist,
                        start = echhist.time.dt.year.values[0], end = echhist.time.dt.year.values[-1])

# %%
ech_clima.coords
# Out:
# Coordinates:
#   * lat      (lat) float64 87.16 83.48 79.78 76.07 ... -79.78 -83.48 -87.16
#   * lon      (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ech_clima.tas.plot(ax = ax, cmap = 'RdBu_r')
ax.set_title('ECH Climatology')
# Out:
# Text(0.5, 1.0, 'ECH Climatology')

# %%
ech1pct_anom = ech1pct - ech_clima

# %%
ech1pct_smean = sn.space_mean(ech1pct_anom.tas).compute()

# %%
ech1pct_smean
# Out:
# <xarray.DataArray (time: 6080)>
# array([-0.11723272,  0.08847581,  0.0936095 , ..., 11.03103541,
#        10.93372189, 11.07065921])
# Coordinates:
#   * time     (time) object 2500-12-31 18:00:00 ... 8579-12-31 18:00:00

# %%
fig, ax = plt.subplots(figsize = (15,5))

ax.plot(ech1pct_smean.time.values, ech1pct_smean.values)

# %% [markdown]
# # KM Tesst

# %%
kstest
# Out:
# <function scipy.stats.stats.kstest(rvs, cdf, args=(), N=20, alternative='two-sided', mode='auto')>

# %%
p1 = ech1pct_smean.isel(time = slice(30,90))
p2 = ech1pct_smean.isel(time = slice(150,210))

# %%
p1
# Out:
# <xarray.DataArray (time: 60)>
# array([0.67945313, 0.44598078, 0.56512792, 0.89283432, 0.74101088,
#        0.76092562, 0.80306391, 0.84886179, 0.9319302 , 0.82638887,
#        0.86188408, 0.85873323, 0.68918486, 1.12509487, 1.29829848,
#        1.08586027, 1.22778036, 1.13590847, 0.89773907, 1.34566983,
#        1.4801985 , 1.15585836, 1.5529486 , 1.56141405, 1.48539234,
#        1.61452466, 1.3520095 , 1.57833463, 1.39818256, 1.37624807,
#        1.85219313, 1.60632014, 1.43565954, 1.78637774, 1.85660259,
#        1.63026898, 2.08364731, 2.25437299, 2.04755256, 2.26057861,
#        2.07835162, 2.14837956, 2.13754622, 2.28679663, 1.92072641,
#        2.38230427, 2.58674833, 2.07491251, 2.44771618, 2.60613001,
#        2.31169241, 2.68805894, 3.13609209, 2.57361256, 2.45695906,
#        2.79996001, 2.55218435, 2.7718818 , 2.88666098, 2.75392082])
# Coordinates:
#   * time     (time) object 2530-12-31 18:00:00 ... 2589-12-31 18:00:00

# %%
kstest(p1,p2)[1]
# Out:
# 2.070073888186965e-35

# %%
WINDOW_LENGTH = 60
WINDOW_DIFF = 60

# %%
len(ech1pct_smean.time.values)
# Out:
# 6080

# %%
effective_length = len(ech1pct_smean.time.values) - (2 * WINDOW_LENGTH + WINDOW_DIFF)
effective_length
# Out:
# 5900

# %%
ks_pval_array = np.zeros(effective_length)
ks_pval_array.shape
# Out:
# (5900,)

# %%
for t in np.arange(effective_length):
    p1 = ech1pct_smean.isel(time = slice(t, t + WINDOW_LENGTH))
    p2 = ech1pct_smean.isel(time = 
                            slice(t + WINDOW_LENGTH + WINDOW_DIFF, t + 2 * WINDOW_LENGTH + WINDOW_DIFF))
    
    ks_pval = kstest(p1,p2)[1]
    
    ks_pval_array[t] += ks_pval

# %%
ks_pval_array
# Out:
# array([2.07007389e-35, 2.07007389e-35, 2.07007389e-35, ...,
#        8.13281299e-01, 9.28437180e-01, 8.13281299e-01])

# %%
ks_pval_ds = xr.DataArray(ks_pval_array,
                          coords = [time], dims = ['time']) #+ pd.to_timedelta(f'{WINDOW_LENGTH/2}Y')],
ks_pval_ds
# Out:
# <xarray.DataArray (time: 5900)>
# array([2.07007389e-35, 2.07007389e-35, 2.07007389e-35, ...,
#        8.13281299e-01, 9.28437180e-01, 8.13281299e-01])
# Coordinates:
#   * time     (time) object 2500-12-31 18:00:00 ... 8399-12-31 18:00:00

# %%
fig = plt.figure(figsize = (15,8))

ax = fig.add_subplot()
time = ech1pct_smean.time.values[:effective_length]

ax.plot(ks_pval_ds.time.values,ks_pval_ds.values)

ax.plot([time[0], time[-1]], [0.05, 0.05], linestyle = ':', linewidth = 2)
ax.plot([time[0], time[-1]], [0.1, 0.1], linestyle = ':', linewidth = 2)

# %%
p2
# Out:
# <xarray.DataArray (time: 60)>
# array([10.79352784, 10.5768594 , 10.79323326, 11.13235676, 10.80797149,
#        10.93495007, 10.98832191, 11.13308306, 10.57223048, 10.5265742 ,
#        10.80017151, 11.03324812, 10.86930639, 11.21292631, 10.99050052,
#        10.8363013 , 11.09717531, 11.09281575, 11.03163569, 10.5330438 ,
#        10.98436042, 10.98994321, 10.51673538, 10.54110679, 10.85546064,
#        10.76317819, 10.99061671, 11.02855635, 11.26566417, 10.93145469,
#        10.72386727, 10.82756678, 11.03699366, 10.98580231, 10.80300769,
#        10.75440931, 11.13830448, 10.77400876, 10.64757667, 10.44277721,
#        10.67057681, 11.13040032, 11.10563012, 10.42414206, 10.72762663,
#        10.97620915, 11.00059028, 11.31212366, 11.5188751 , 10.90791973,
#        10.7814195 , 10.73370637, 10.66909731, 10.93844156, 11.27151589,
#        10.57165168, 10.57156875, 10.94655557, 11.03103541, 10.93372189])
# Coordinates:
#   * time     (time) object 8519-12-31 18:00:00 ... 8578-12-31 18:00:00

# %%
ech1pct_smean.time.values
# Out:
# array([cftime.DatetimeGregorian(2500, 12, 31, 18, 0, 0, 0),
#        cftime.DatetimeGregorian(2501, 12, 31, 18, 0, 0, 0),
#        cftime.DatetimeGregorian(2502, 12, 31, 18, 0, 0, 0), ...,
#        cftime.DatetimeGregorian(8577, 12, 31, 18, 0, 0, 0),
#        cftime.DatetimeGregorian(8578, 12, 31, 18, 0, 0, 0),
#        cftime.DatetimeGregorian(8579, 12, 31, 18, 0, 0, 0)], dtype=object)

# %%
ks_pval_ds.time.values
# Out:
# array([cftime.DatetimeGregorian(2500, 12, 31, 18, 0, 0, 0),
#        cftime.DatetimeGregorian(2501, 12, 31, 18, 0, 0, 0),
#        cftime.DatetimeGregorian(2502, 12, 31, 18, 0, 0, 0), ...,
#        cftime.DatetimeGregorian(8397, 12, 31, 18, 0, 0, 0),
#        cftime.DatetimeGregorian(8398, 12, 31, 18, 0, 0, 0),
#        cftime.DatetimeGregorian(8399, 12, 31, 18, 0, 0, 0)], dtype=object)

# %%
fig = plt.figure(figsize = (15,8))

ax = fig.add_subplot()

# The p-values
time = ks_pval_ds.time.values
ax.plot(time,ks_pval_ds.values)


# Adding in bounds for different p-values
ax.plot([time[0], time[-1]], [0.05, 0.05], linestyle = ':', linewidth = 2)
ax.plot([time[0], time[-1]], [0.1, 0.1], linestyle = ':', linewidth = 2)
ax.set_ylim([np.nanmin(ks_pval_array), np.nanmax(ks_pval_array) + 0.3])
c1 = plt.gca().lines[0].get_color()
ax.tick_params(axis = 'y', labelcolor = c1)
ax.set_ylabel('p-vaue', size = 15, c = c1)


# The temperature anomalies
ax2 = ax.twinx()
time = ech1pct_smean.time.values[:effective_length]

ax2.plot(ech1pct_smean.time.values, ech1pct_smean.values, color = 'green', alpha = 0.5);
c2 = plt.gca().lines[0].get_color()
ax2.tick_params(axis = 'y', labelcolor = c2)
ax2.spines['right'].set_color(c2)
ax2.set_ylabel('GMST Anomaly', size = 15, c = c2)

ax2.spines['left'].set_color(c1)

# %%
plt.hist(ks_pval_array)
# Out:
# (array([2091.,  585.,  404.,  542.,    0.,  624.,  534.,    0.,  494.,
#          626.]),
#  array([2.07007389e-35, 9.99999707e-02, 1.99999941e-01, 2.99999912e-01,
#         3.99999883e-01, 4.99999854e-01, 5.99999824e-01, 6.99999795e-01,
#         7.99999766e-01, 8.99999737e-01, 9.99999707e-01]),
#  <BarContainer object of 10 artists>)

# %%
len(ks_pval_array)
# Out:
# 5900

# %%
len(np.where(ks_pval_array < 0.05)[0])
# Out:
# 1834

# %%
np.where(ks_pval_array < 0.05)[0][-100:-80]
# Out:
# array([4952, 4953, 4956, 4957, 5128, 5129, 5140, 5141, 5142, 5143, 5144,
#        5145, 5146, 5285, 5286, 5298, 5300, 5301, 5302, 5303])

# %%
np.where?
