# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('../functions')

# %%
import animation_functions as anim

# %%
from importlib import reload

# %% [markdown]
# # Local File

# %%
ROOT_DIR1 = '/g/data/oi10/replicas/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G/abrupt-4xCO2/r102i1p1f1/Amon/ts/gn/v20190815/'

# %%
abrupt4 = xr.open_dataset(ROOT_DIR1 + 'ts_Amon_GISS-E2-1-G_abrupt-4xCO2_r102i1p1f1_gn_185001-190012.nc').ts

# %%
abrupt4
# Out:
# <xarray.DataArray 'ts' (time: 612, lat: 90, lon: 144)>
# [7931520 values with dtype=float32]
# Coordinates:
#   * time     (time) object 1850-01-16 12:00:00 ... 1900-12-16 12:00:00
#   * lat      (lat) float64 -89.0 -87.0 -85.0 -83.0 -81.0 ... 83.0 85.0 87.0 89.0
#   * lon      (lon) float64 1.25 3.75 6.25 8.75 11.25 ... 351.2 353.8 356.2 358.8
# Attributes:
#     standard_name:  surface_temperature
#     long_name:      Surface Temperature
#     comment:        Temperature of the lower boundary of the atmosphere
#     units:          K
#     cell_methods:   area: time: mean
#     cell_measures:  area: areacella
#     history:        2019-08-19T19:40:51Z altered by CMOR: replaced missing va...

# %%
abrupt4.time.values[0],abrupt4.time.values[-1]
# Out:
# (cftime.DatetimeNoLeap(1850, 1, 16, 12, 0, 0, 0),
#  cftime.DatetimeNoLeap(1900, 12, 16, 12, 0, 0, 0))

# %%
abrupt4.isel(time = 10).plot()

# %% [markdown]
# # Creating Animation

# %%
anim = reload(anim)

# %%
 anim.set_animimate_plot(abrupt4, name = 'test5')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     250         try:
# --> 251             yield self
#     252         finally:
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1140                     # TODO: See if turning off blit is really necessary
# -> 1141                     anim._draw_next_frame(d, blit=False)
#    1142                     if progress_callback is not None:
#
# ...

# %% [markdown]
# <img src = "test5.gif" width="750" align="center">

# %%
abrupt4
# Out:
# <xarray.DataArray 'ts' (time: 612, lat: 90, lon: 144)>
# [7931520 values with dtype=float32]
# Coordinates:
#   * time     (time) object 1850-01-16 12:00:00 ... 1900-12-16 12:00:00
#   * lat      (lat) float64 -89.0 -87.0 -85.0 -83.0 -81.0 ... 83.0 85.0 87.0 89.0
#   * lon      (lon) float64 1.25 3.75 6.25 8.75 11.25 ... 351.2 353.8 356.2 358.8
# Attributes:
#     standard_name:  surface_temperature
#     long_name:      Surface Temperature
#     comment:        Temperature of the lower boundary of the atmosphere
#     units:          K
#     cell_methods:   area: time: mean
#     cell_measures:  area: areacella
#     history:        2019-08-19T19:40:51Z altered by CMOR: replaced missing va...

# %%
anim = reload(anim) 
anim.unset_animimate_plot(abrupt4, name = 'unset1')

# %% [markdown]
# <img src = "unset1.gif">

# %%
anim = reload(anim) 
anim.unset_animimate_plot(abrupt4, name = 'unset2', time_frac = 30)

# %% [markdown]
# <img src = "unset2.gif">
