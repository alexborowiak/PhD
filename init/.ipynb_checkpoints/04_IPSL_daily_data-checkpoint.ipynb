# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt

# %%
ROOT_DIR = '/g/data/oi10/replicas/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp585/r1i1p1f1/day/tas/gr/v20190903/'
ROOT_DIR0 = '/g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r1i1p1f1/day/tas/gr/v20190614/'

# %%
# %%bash
# ls /g/data/oi10/replicas/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp585/r1i1p1f1/day/tas/gr/v20190903
# Out:
# tas_day_IPSL-CM6A-LR_ssp585_r1i1p1f1_gr_20150101-21001231.nc
# tas_day_IPSL-CM6A-LR_ssp585_r1i1p1f1_gr_21010101-23001231.nc

# %%
# %%bash
# ls /g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r1i1p1f1/day/tas/gr/v20190614
# Out:
# tas_day_IPSL-CM6A-LR_historical_r1i1p1f1_gr_18500101-20141231.nc

# %%
f0 = xr.open_dataset(ROOT_DIR0 + 'tas_day_IPSL-CM6A-LR_historical_r1i1p1f1_gr_18500101-20141231.nc')

# %%
f1 = xr.open_mfdataset(ROOT_DIR + '*.nc')
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/xarray/coding/times.py:463: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/xarray/coding/times.py:463: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/numpy/core/_asarray.py:83: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
f0
# Out:
# <xarray.Dataset>
# Dimensions:      (axis_nbounds: 2, lat: 143, lon: 144, time: 60265)
# Coordinates:
#   * lat          (lat) float32 -90.0 -88.73 -87.46 -86.2 ... 87.46 88.73 90.0
#   * lon          (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#     height       float64 ...
#   * time         (time) datetime64[ns] 1850-01-01T12:00:00 ... 2014-12-31T12:...
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     time_bounds  (time, axis_nbounds) datetime64[ns] ...
#     tas          (time, lat, lon) float32 ...
# Attributes:
#     Conventions:            CF-1.7 CMIP-6.2
#     creation_date:          2018-07-11T07:27:15Z
#     description:            CMIP6 historical
#     title:                  IPSL-CM6A-LR model output prepared for CMIP6 / CM...
#     activity_id:            CMIP
#     contact:                ipsl-cmip6@listes.ipsl.fr
#     data_specs_version:     01.00.21
#     dr2xml_version:         1.11
#     experiment_id:          historical
# ...

# %%
f1
# Out:
# <xarray.Dataset>
# Dimensions:      (axis_nbounds: 2, lat: 143, lon: 144, time: 104459)
# Coordinates:
#   * lat          (lat) float32 -90.0 -88.73 -87.46 -86.2 ... 87.46 88.73 90.0
#   * lon          (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#     height       float64 2.0
#   * time         (time) object 2015-01-01T12:00:00 ... 2300-12-31 12:00:00
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     time_bounds  (time, axis_nbounds) object dask.array<chunksize=(31411, 2), meta=np.ndarray>
#     tas          (time, lat, lon) float32 dask.array<chunksize=(31411, 143, 144), meta=np.ndarray>
# Attributes:
#     name:                   /ccc/work/cont003/gencmip6/oboucher/IGCM_OUT/IPSL...
#     Conventions:            CF-1.7 CMIP-6.2
#     creation_date:          2018-12-18T20:56:09Z
#     description:            Future scenario with high radiative forcing by th...
#     title:                  IPSL-CM6A-LR model output prepared for CMIP6 / Sc...
# ...

# %% [markdown]
# # Sample Plots

# %%
f1_mean = f1.tas.mean(dim = ['lat','lon']) - f1.tas.mean(dim = ['time','lat','lon'])

# %%
f1_mean
# Out:
# <xarray.DataArray 'tas' (time: 104459)>
# dask.array<sub, shape=(104459,), dtype=float32, chunksize=(73048,), chunktype=numpy.ndarray>
# Coordinates:
#     height   float64 2.0
#   * time     (time) object 2015-01-01T12:00:00 ... 2300-12-31 12:00:00

# %%
f1_mean_roll = f1_mean.rolling(time = 3000, center = True).mean()
f1_mean_roll
# Out:
# <xarray.DataArray 'tas' (time: 104459)>
# dask.array<where, shape=(104459,), dtype=float32, chunksize=(73047,), chunktype=numpy.ndarray>
# Coordinates:
#     height   float64 2.0
#   * time     (time) object 2015-01-01T12:00:00 ... 2300-12-31 12:00:00

# %%
fig = plt.figure(figsize = (10,10))
f1_mean.plot()
f1_mean_roll.plot()

# %%
f0_mean = f0.tas.mean(dim  = ['lat','lon'])

# %%
f0_mean
# Out:
# <xarray.DataArray 'tas' (time: 60265)>
# array([275.4801 , 275.34106, 274.9463 , ..., 277.0186 , 276.86557,
#        276.6097 ], dtype=float32)
# Coordinates:
#     height   float64 2.0
#   * time     (time) datetime64[ns] 1850-01-01T12:00:00 ... 2014-12-31T12:00:00

# %%
f0_mean.plot()

# %% [markdown]
# # Global Mean anomalies relative to pre-indistrial

# %%
# %%bash
# ls /g/data/oi10/replicas/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp585/r1i1p1f1/Amon/tas/gr/v20190903
# Out:
# tas_Amon_IPSL-CM6A-LR_ssp585_r1i1p1f1_gr_201501-210012.nc
# tas_Amon_IPSL-CM6A-LR_ssp585_r1i1p1f1_gr_210101-230012.nc

# %%
ROOT_DIR1 = '/g/data/oi10/replicas/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp585/r1i1p1f1/Amon/tas/gr/v20190903/'

# %%
t1 = xr.open_dataset(ROOT_DIR1 + 'tas_Amon_IPSL-CM6A-LR_ssp585_r1i1p1f1_gr_201501-210012.nc')

# %%
t2 = xr.open_dataset(ROOT_DIR1 + 'tas_Amon_IPSL-CM6A-LR_ssp585_r1i1p1f1_gr_210101-230012.nc')
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/xarray/coding/times.py:463: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/xarray/coding/times.py:463: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/numpy/core/_asarray.py:83: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
d0.time.dt.year.values
# Out:
# array([1850, 1850, 1850, ..., 2014, 2014, 2014])

# %%
t2.time.dt.year.values
# Out:
# array([2101, 2101, 2101, ..., 2300, 2300, 2300])

# %%
t1.time.dt.year.values
# Out:
# array([2015, 2015, 2015, ..., 2100, 2100, 2100])

# %%
t_stor = []
for i in t2.time.values:
    time = np.datetime64(i)
    t_stor.append(time)

# %%
t_stor
# Out:
# [numpy.datetime64('2101-01-16T12:00:00.000000'),
#  numpy.datetime64('2101-02-15T00:00:00.000000'),
#  numpy.datetime64('2101-03-16T12:00:00.000000'),
#  numpy.datetime64('2101-04-16T00:00:00.000000'),
#  numpy.datetime64('2101-05-16T12:00:00.000000'),
#  numpy.datetime64('2101-06-16T00:00:00.000000'),
#  numpy.datetime64('2101-07-16T12:00:00.000000'),
#  numpy.datetime64('2101-08-16T12:00:00.000000'),
#  numpy.datetime64('2101-09-16T00:00:00.000000'),
#  numpy.datetime64('2101-10-16T12:00:00.000000'),
#  numpy.datetime64('2101-11-16T00:00:00.000000'),
#  numpy.datetime64('2101-12-16T12:00:00.000000'),
#  numpy.datetime64('2102-01-16T12:00:00.000000'),
#  numpy.datetime64('2102-02-15T00:00:00.000000'),
#  numpy.datetime64('2102-03-16T12:00:00.000000'),
#  numpy.datetime64('2102-04-16T00:00:00.000000'),
#  numpy.datetime64('2102-05-16T12:00:00.000000'),
#  numpy.datetime64('2102-06-16T00:00:00.000000'),
#  numpy.datetime64('2102-07-16T12:00:00.000000'),
# ...

# %%
np.datetime64(t2.time.values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-162-ec04e0e67173> in <module>
# ----> 1 np.datetime64(t2.time.values)
#
# ValueError: Could not convert object to NumPy datetime

# %%
np.datetime64(t2.time.values[0])
# Out:
# numpy.datetime64('2101-01-16T12:00:00.000000')

# %%
type(t2.time.values[0])
# Out:
# cftime._cftime.DatetimeGregorian

# %%
t1.time.values
# Out:
# array(['2015-01-16T12:00:00.000000000', '2015-02-15T00:00:00.000000000',
#        '2015-03-16T12:00:00.000000000', ...,
#        '2100-10-16T12:00:00.000000000', '2100-11-16T00:00:00.000000000',
#        '2100-12-16T12:00:00.000000000'], dtype='datetime64[ns]')

# %%
t2.time.values
# Out:
# array([cftime.DatetimeGregorian(2101, 1, 16, 12, 0, 0, 0),
#        cftime.DatetimeGregorian(2101, 2, 15, 0, 0, 0, 0),
#        cftime.DatetimeGregorian(2101, 3, 16, 12, 0, 0, 0), ...,
#        cftime.DatetimeGregorian(2300, 10, 16, 12, 0, 0, 0),
#        cftime.DatetimeGregorian(2300, 11, 16, 0, 0, 0, 0),
#        cftime.DatetimeGregorian(2300, 12, 16, 12, 0, 0, 0)], dtype=object)

# %%
# %%bash
# ls /g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r1i1p1f1/Amon/tas/gr/v20180803
# Out:
# tas_Amon_IPSL-CM6A-LR_historical_r1i1p1f1_gr_185001-201412.nc

# %%
ROOT_DIR1 = '/g/data/oi10/replicas/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp585/r1i1p1f1/Amon/tas/gr/v20190903/'
ROOT_DIR0 = '/g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r1i1p1f1/Amon/tas/gr/v20180803/'

# %%
d0 = xr.open_dataset(ROOT_DIR0 + 'tas_Amon_IPSL-CM6A-LR_historical_r1i1p1f1_gr_185001-201412.nc')

# %%
d1 = xr.open_mfdataset(ROOT_DIR1 + "*.nc")
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/xarray/coding/times.py:463: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/xarray/coding/times.py:463: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/numpy/core/_asarray.py:83: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
d1.isel(time = slice(-10,-5)).time.values
# Out:
# array([cftime.DatetimeGregorian(2300, 3, 16, 12, 0, 0, 0),
#        cftime.DatetimeGregorian(2300, 4, 16, 0, 0, 0, 0),
#        cftime.DatetimeGregorian(2300, 5, 16, 12, 0, 0, 0),
#        cftime.DatetimeGregorian(2300, 6, 16, 0, 0, 0, 0),
#        cftime.DatetimeGregorian(2300, 7, 16, 12, 0, 0, 0)], dtype=object)

# %%
d1.isel(time = slice(-10,-5)).time.to_datetimeindex()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-a6b81bcd55a0> in <module>
# ----> 1 d1.isel(time = slice(-10,-5)).time.to_datetimeindex()
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/xarray/core/common.py in __getattr__(self, name)
#     226                 with suppress(KeyError):
#     227                     return source[name]
# --> 228         raise AttributeError(
#     229             "{!r} object has no attribute {!r}".format(type(self).__name__, name)
#     230         )
#
# AttributeError: 'DataArray' object has no attribute 'to_datetimeindex'

# %%
d0.time.values
# Out:
# array(['1850-01-16T12:00:00.000000000', '1850-02-15T00:00:00.000000000',
#        '1850-03-16T12:00:00.000000000', ...,
#        '2014-10-16T12:00:00.000000000', '2014-11-16T00:00:00.000000000',
#        '2014-12-16T12:00:00.000000000'], dtype='datetime64[ns]')

# %%
d0
# Out:
# <xarray.Dataset>
# Dimensions:      (axis_nbounds: 2, lat: 143, lon: 144, time: 1980)
# Coordinates:
#   * lat          (lat) float32 -90.0 -88.73 -87.46 -86.2 ... 87.46 88.73 90.0
#   * lon          (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#     height       float64 ...
#   * time         (time) datetime64[ns] 1850-01-16T12:00:00 ... 2014-12-16T12:...
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     time_bounds  (time, axis_nbounds) datetime64[ns] ...
#     tas          (time, lat, lon) float32 ...
# Attributes:
#     Conventions:            CF-1.7 CMIP-6.2
#     creation_date:          2018-07-11T07:36:34Z
#     tracking_id:            hdl:21.14100/285a3a27-0287-4e3b-8232-69ddc89cebef
#     description:            CMIP6 historical
#     title:                  IPSL-CM6A-LR model output prepared for CMIP6 / CM...
#     activity_id:            CMIP
#     contact:                ipsl-cmip6@listes.ipsl.fr
# ...

# %%
d1
# Out:
# <xarray.Dataset>
# Dimensions:      (axis_nbounds: 2, lat: 143, lon: 144, time: 3432)
# Coordinates:
#   * lat          (lat) float32 -90.0 -88.73 -87.46 -86.2 ... 87.46 88.73 90.0
#   * lon          (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#     height       float64 2.0
#   * time         (time) object 2015-01-16T12:00:00 ... 2300-12-16 12:00:00
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     time_bounds  (time, axis_nbounds) object dask.array<chunksize=(1032, 2), meta=np.ndarray>
#     tas          (time, lat, lon) float32 dask.array<chunksize=(1032, 143, 144), meta=np.ndarray>
# Attributes:
#     name:                   /ccc/work/cont003/gencmip6/oboucher/IGCM_OUT/IPSL...
#     Conventions:            CF-1.7 CMIP-6.2
#     creation_date:          2018-12-18T21:02:30Z
#     tracking_id:            hdl:21.14100/131c5ed5-c3f0-4c3a-bbc8-f66ed7799e03
#     description:            Future scenario with high radiative forcing by th...
# ...

# %%
d0.time.values[-1]
# Out:
# numpy.datetime64('2014-12-16T12:00:00.000000000')

# %%
d1.time.values[0]
# Out:
# Timestamp('2015-01-16 12:00:00')

# %%
d = d0.combine_first(d1)

# %%
d
# Out:
# <xarray.Dataset>
# Dimensions:      (axis_nbounds: 2, lat: 143, lon: 144, time: 5412)
# Coordinates:
#   * time         (time) object 1850-01-16T12:00:00 ... 2300-12-16 12:00:00
#   * lat          (lat) float32 -90.0 -88.73 -87.46 -86.2 ... 87.46 88.73 90.0
#   * lon          (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#     height       float64 2.0
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     time_bounds  (time, axis_nbounds) object dask.array<chunksize=(3012, 2), meta=np.ndarray>
#     tas          (time, lat, lon) float32 dask.array<chunksize=(3012, 143, 144), meta=np.ndarray>
# Attributes:
#     Conventions:            CF-1.7 CMIP-6.2
#     creation_date:          2018-07-11T07:36:34Z
#     tracking_id:            hdl:21.14100/285a3a27-0287-4e3b-8232-69ddc89cebef
#     description:            CMIP6 historical
#     title:                  IPSL-CM6A-LR model output prepared for CMIP6 / CM...
#     activity_id:            CMIP
# ...

# %%
d.time.values[-1]
# Out:
# cftime.DatetimeGregorian(2300, 12, 16, 12, 0, 0, 0)

# %%
type(d.time.values[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(d.time.values[-1])
# Out:
# cftime._cftime.DatetimeGregorian

# %%
plt.plot(d.time.values)

# %%
d.time.to_datetimeindex()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-dfd5c3ef2b16> in <module>
# ----> 1 d.time.to_datetimeindex()
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/xarray/core/common.py in __getattr__(self, name)
#     226                 with suppress(KeyError):
#     227                     return source[name]
# --> 228         raise AttributeError(
#     229             "{!r} object has no attribute {!r}".format(type(self).__name__, name)
#     230         )
#
# AttributeError: 'DataArray' object has no attribute 'to_datetimeindex'

# %%
d_mean = d.tas.mean(dim = ['lat','lon']) - d0.where(d0.time.dt.year.isin(np.arange(1850,1901)), drop = True).mean(dim = ['lat','lon'])

# %%
d_mean
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 612)
# Coordinates:
#   * time     (time) object 1850-01-16T12:00:00 ... 1900-12-16T12:00:00
#     height   float64 2.0
# Data variables:
#     tas      (time) float32 dask.array<chunksize=(612,), meta=np.ndarray>

# %%
d_mean.plot()
