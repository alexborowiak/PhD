# %% [markdown]
# # Saving Loess Detrended Data
# Saving all data with loess detrend.

# %%
import xarray as xr
from importlib import reload
import numpy as np
import pandas as pd
import os

import xarray_class_accessors as xca
import signal_to_noise as sn

# %%
control_chunks = {'lat':48/2,'lon':96/2,'time':-1}

# %%
ROOT_DIR = '/g/data/w40/ab2313/longrunmip/regrid_retimestamped'

# %%
os.listdir(ROOT_DIR)[:5]
# Out:
# ['tas_ann_HadGEM2_control_239_g025.nc',
#  'tas_mon_HadCM3L_control_1000_g025.nc',
#  'tas_mon_GFDLCM3_control_5200_g025.nc',
#  'tas_mon_ECHAM5MPIOM_abrupt4x_1001_g025.nc',
#  'tas_mon_GFDLCM3_1pct2x_5000_g025.nc']

# %%
path_control = os.path.join(ROOT_DIR, 'tas_mon_MPIESM12_control_1237_g025.nc')
path_control
# Out:
# '/g/data/w40/ab2313/longrunmip/regrid_retimestamped/tas_mon_MPIESM12_control_1237_g025.nc'

# %%
path_abrupt4 = os.path.join(ROOT_DIR, 'tas_ann_MPIESM11_abrupt4x_4459_g025.nc')
path_abrupt4
# Out:
# '/g/data/w40/ab2313/longrunmip/regrid_retimestamped/tas_ann_MPIESM11_abrupt4x_4459_g025.nc'

# %%
control = xr.open_dataset(path_control,use_cftime = True, chunks = control_chunks).tas
control = control.rename({'month':'time'})

# %%
control
# Out:
# <xarray.DataArray 'tas' (time: 14844, lat: 72, lon: 144)>
# dask.array<open_dataset-b5c03d26e699f362d1e5c40f0349cabetas, shape=(14844, 72, 144), dtype=float32, chunksize=(14844, 24, 48), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float64 1.25 3.75 6.25 8.75 11.25 ... 351.2 353.8 356.2 358.8
#   * lat      (lat) float64 -88.75 -86.25 -83.75 -81.25 ... 83.75 86.25 88.75
#   * time     (time) object 0000-01-31 00:00:00 ... 1236-12-31 00:00:00
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Near-Surface Air Temperature
#     units:          K
#     code:           167
#     table:          128
#     original_name:  tas
#     cell_methods:   time: mean

# %%
control = control.resample(time='Y').mean()
control
# Out:
# <xarray.DataArray 'tas' (time: 1237, lat: 72, lon: 144)>
# dask.array<stack, shape=(1237, 72, 144), dtype=float32, chunksize=(1, 24, 48), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 0000-12-31 00:00:00 ... 1236-12-31 00:00:00
#   * lon      (lon) float64 1.25 3.75 6.25 8.75 11.25 ... 351.2 353.8 356.2 358.8
#   * lat      (lat) float64 -88.75 -86.25 -83.75 -81.25 ... 83.75 86.25 88.75

# %%
climatology = control.clima.climatology(start = control.time.dt.year.values[0], 
                                          end = control.time.dt.year.values[-1])
climatology
# Out:
# <xarray.DataArray 'tas' (lat: 72, lon: 144)>
# dask.array<mean_agg-aggregate, shape=(72, 144), dtype=float32, chunksize=(24, 48), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float64 1.25 3.75 6.25 8.75 11.25 ... 351.2 353.8 356.2 358.8
#   * lat      (lat) float64 -88.75 -86.25 -83.75 -81.25 ... 83.75 86.25 88.75

# %%
climatology.plot()

# %%
# Calulating the anomalies from the climatology that is based upon itself.
control_anomalies = control.clima.anomalies(start = control.time.dt.year.values[0], 
                                          end = control.time.dt.year.values[-1])

# %%
# Getting the space mean
control_anomalies_smean = control_anomalies.clima.space_mean()

# %%
control_anomalies_smean
# Out:
# <xarray.DataArray 'tas' (time: 1237)>
# dask.array<truediv, shape=(1237,), dtype=float64, chunksize=(8,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 0000-12-31 00:00:00 ... 1236-12-31 00:00:00

# %%
control_anomalies_smean.plot()

# %% [markdown]
# # Loess Filter

# %%
loess_control = control_anomalies_smean.sn.loess_grid()

# %%
loess_control
# Out:
# <xarray.DataArray 'tas' (time: 1237)>
# dask.array<sub, shape=(1237,), dtype=float64, chunksize=(8,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 0000-12-31 00:00:00 ... 1236-12-31 00:00:00

# %%
loess_control.plot()

# %%
# %%time
loess_control_grid = control_anomalies.sn.loess_grid()
# Out:
# CPU times: user 36min 43s, sys: 13.6 s, total: 36min 56s
# Wall time: 37min 11s

# %%
# Adding some attributes
now = pd.Timestamp.now().strftime(format = '%Y/%m/%d')
loess_control_grid.attrs = {'history': f'Modified by Alex Borowiak on {now}','stats': 'loess detrended data'}

# %%
loess_control_grid
# Out:
# <xarray.DataArray 'tas' (time: 1237, lat: 72, lon: 144)>
# dask.array<sub, shape=(1237, 72, 144), dtype=float64, chunksize=(8, 24, 48), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 0000-12-31 00:00:00 ... 1236-12-31 00:00:00
#   * lon      (lon) float64 1.25 3.75 6.25 8.75 11.25 ... 351.2 353.8 356.2 358.8
#   * lat      (lat) float64 -88.75 -86.25 -83.75 -81.25 ... 83.75 86.25 88.75
# Attributes:
#     history:  Modified by Alex Borowiak on 2021/11/23
#     stats:    loess detrended data

# %%
loess_control_grid.to_netcdf(os.path.join(ROOT_DIR,'loess', 'tas_ann_MPIESM11_abrupt4x_4459_g025_loess.nc'))

# %% [markdown]
# # Streamlined
# No step through. Just the important steps.

# %%
quadco2 = xr.open_dataset(f'{ROOT_DIR}/tas_mon_CCSM3_abrupt4x_2120.nc',
                             use_cftime = True, chunks = {'lat':100,'lon':100}).tas

# Applying correctinos to the data.
quadco2 = quadco2.correct_data.apply_corrections()
# Out:
# Testing months in each year...
# Inital time length: 25440
# - First year removed: 11 month(s) in year 1
# - Last year removed:  1 month(s) in year 2121
# - Incorrect year detected and time overridden
#
# Data Correction complete - all years now have 12 months
# Final time length: 25428

# %%
quadco2_yearmean = quadco2.resample(time = 'Y').mean(dim = 'time')

# %%
quadco2_anom = quadco2_yearmean.clima.anomalies(start = control.time.dt.year.values[0], 
                                          end = control.time.dt.year.values[-1],
                            historical = control)
# Out:
# Using historical dataset

# %%
quadco2_anom_smean = quadco2_anom.clima.space_mean()

# %%
quadco2_anom_smean.plot()

# %%
# %%time
loess_quadco2 = quadco2_anom.sn.loess_grid()
# Out:
# CPU times: user 29min 35s, sys: 4 s, total: 29min 39s
# Wall time: 29min 50s

# %%
# Adding some attributes
now = pd.Timestamp.now().strftime(format = '%Y/%m/%d')
loess_quadco2.attrs = {'history': f'Modified by Alex Borowiak on {now}','stats': 'loess detrended data'}

# %%
loess_quadco2.to_netcdf(os.path.join(ROOT_DIR, 'loess', 'tas_mon_CCSM3_abrupt4x_2120.nc'))
