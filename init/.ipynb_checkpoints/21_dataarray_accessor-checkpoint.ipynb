# %%
import xarray as xr
import sn_register_dataarray_accessor
from importlib import reload

# %%
ROOT_DIR = '/g/data/w40/ab2313/longrunmip'

# %%
quadco2 = xr.open_dataset(f'{ROOT_DIR}/tas_mon_CCSM3_abrupt4x_2120.nc',
                             use_cftime = True, chunks = {'lat':100,'lon':100})

# %%
quadco2
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 48, lon: 96, time: 25440)
# Coordinates:
#   * time     (time) object 0001-02-01 00:00:00 ... 2121-01-01 00:00:00
#   * lat      (lat) float64 -87.16 -83.48 -79.78 -76.07 ... 79.78 83.48 87.16
#   * lon      (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2
# Data variables:
#     tas      (time, lat, lon) float32 dask.array<chunksize=(25440, 48, 96), meta=np.ndarray>

# %%
quadco2_mean = quadco2.tas.mean(dim = ['lat','lon'])

# %%
quadco2_mean
# Out:
# <xarray.DataArray 'tas' (time: 25440)>
# dask.array<mean_agg-aggregate, shape=(25440,), dtype=float32, chunksize=(25440,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 0001-02-01 00:00:00 ... 2121-01-01 00:00:00

# %%
quadco2_mean.sn.consecutive_counter(30)
# Out:
# Alex
# (array([0]), array([25440]))
