# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
ROOT_DIR = '/g/data/oi10/replicas/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G/abrupt-4xCO2/r102i1p1f1/Amon/ts/gn/v20190815/'

# %%
d1 = xr.open_dataset(ROOT_DIR + 'ts_Amon_GISS-E2-1-G_abrupt-4xCO2_r102i1p1f1_gn_185001-190012.nc').ts

# %%
d1
# Out:
# <xarray.DataArray 'ts' (time: 612, lat: 90, lon: 144)>
# [7931520 values with dtype=float32]
# Coordinates:
#   * time     (time) object 1850-01-16 12:00:00 ... 1900-12-16 12:00:00
#   * lat      (lat) float64 -89.0 -87.0 -85.0 -83.0 -81.0 ... 83.0 85.0 87.0 89.0
#   * lon      (lon) float64 1.25 3.75 6.25 8.75 11.25 ... 351.2 353.8 356.2 358.8
# Attributes:
#     standard_name:  surface_temperature
#     long_name:      Surface Temperature
#     comment:        Temperature of the lower boundary of the atmosphere
#     units:          K
#     cell_methods:   area: time: mean
#     cell_measures:  area: areacella
#     history:        2019-08-19T19:40:51Z altered by CMOR: replaced missing va...

# %%
d1.isel(time = 10).plot()

# %%
from matplotlib import animation, rc
from IPython.display import HTML

# %%
fig, ax = plt.subplots()
line, = ax.plot([],[],lw=2)

# %%
X,Y = np.meshgrid(d1.lon, d1.lat)

# %%
plt.pcolormesh(X,Y, d1.isel(time = 0).values, shading = 'nearest')

# %%
def animate(time):
    ax.pcolormesh(X,Y, d1.isel(time = time).values, shading = 'nearest')

# %%
num_frames = len(d1.time.values)
num_frames
# Out:
# 612

# %%
amin = animation.FuncAnimation(fig, animate, frames = num_frames, interval  = 20, blit = True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-37-cf49d0fe1c73> in <module>
# ----> 1 amin = animation.FuncAnimation(fig, plot_dude, frames = num_frames, interval  = 20, blit = True)
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/animation.py in __init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1654         self._save_seq = []
#    1655
# -> 1656         TimedAnimation.__init__(self, fig, **kwargs)
#    1657
#    1658         # Need to reset the saved seq, since right now it will contain data
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/animation.py in __init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1413         if event_source is None:
#    1414             event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1415         Animation.__init__(self, fig, event_source=event_source,
#    1416                            *args, **kwargs)
#    1417
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/animation.py in __init__(self, fig, event_source, blit)
#     943                                                       self._stop)
#     944         if self._blit:
# --> 945             self._setup_blit()
#     946
#     947     def _start(self, *args):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/animation.py in _setup_blit(self)
#    1247         self._resize_id = self._fig.canvas.mpl_connect('resize_event',
#    1248                                                        self._on_resize)
# -> 1249         self._post_draw(None, self._blit)
#    1250
#    1251     def _on_resize(self, event):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/animation.py in _post_draw(self, framedata, blit)
#    1200             self._blit_draw(self._drawn_artists)
#    1201         else:
# -> 1202             self._fig.canvas.draw_idle()
#    1203
#    1204     # The rest of the code in this class is to facilitate easy blitting
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2010         if not self._is_idle_drawing:
#    2011             with self._idle_draw_cntx():
# -> 2012                 self.draw(*args, **kwargs)
#    2013
#    2014     @cbook.deprecated("3.2")
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1868             self.stale = False
#    1869
# -> 1870         self.canvas.draw_event(renderer)
#    1871
#    1872     def draw_artist(self, a):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/backend_bases.py in draw_event(self, renderer)
#    1757         s = 'draw_event'
#    1758         event = DrawEvent(s, self, renderer)
# -> 1759         self.callbacks.process(s, event)
#    1760
#    1761     def resize_event(self):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     227                 except Exception as exc:
#     228                     if self.exception_handler is not None:
# --> 229                         self.exception_handler(exc)
#     230                     else:
#     231                         raise
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in _exception_printer(exc)
#      79 def _exception_printer(exc):
#      80     if _get_running_interactive_framework() in ["headless", None]:
# ---> 81         raise exc
#      82     else:
#      83         traceback.print_exc()
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     222             if func is not None:
#     223                 try:
# --> 224                     func(*args, **kwargs)
#     225                 # this does not capture KeyboardInterrupt, SystemExit,
#     226                 # and GeneratorExit
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/animation.py in _start(self, *args)
#     957
#     958         # Now do any initial draw
# --> 959         self._init_draw()
#     960
#     961         # Add our callback for stepping the animation and
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/animation.py in _init_draw(self)
#    1701         # artists.
#    1702         if self._init_func is None:
# -> 1703             self._draw_frame(next(self.new_frame_seq()))
#    1704
#    1705         else:
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-20.10/lib/python3.8/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1727         if self._blit:
#    1728             if self._drawn_artists is None:
# -> 1729                 raise RuntimeError('The animation function must return a '
#    1730                                    'sequence of Artist objects.')
#    1731             self._drawn_artists = sorted(self._drawn_artists,
#
# RuntimeError: The animation function must return a sequence of Artist objects.

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
import matplotlib.animation as animation

y, x = np.meshgrid(np.linspace(-10, 10,100), np.linspace(-10, 10,100))

z = np.sin(x)*np.sin(x)+np.sin(y)*np.sin(y)

v = np.linspace(-10, 10,100)
t = np.sin(v)*np.sin(v)
tt = np.cos(v)*np.cos(v)
###########

fig = plt.figure(figsize=(16, 8),facecolor='white')
gs = gridspec.GridSpec(5, 2)
ax1 = plt.subplot(gs[0,0])

# line, = ax1.plot([],[],'b-.',linewidth=2)
# ax1.set_xlim(-10,10)
# ax1.set_ylim(0,1)
# ax1.set_xlabel('time')
# ax1.set_ylabel('amplitude')
# ax1.set_title('Oscillationsssss')
# time_text = ax1.text(0.02, 0.95, '', transform=ax1.transAxes)

# #############################
ax2 = plt.subplot(gs[1:3,0])
quad1 = ax2.pcolormesh(x,y,z,shading='gouraud')
ax2.set_xlabel('time')
ax2.set_ylabel('amplitude')
cb2 = fig.colorbar(quad1,ax=ax2)

#########################
# ax3 = plt.subplot(gs[3:,0])
# quad2 = ax3.pcolormesh(x, y, z,shading='gouraud')
# ax3.set_xlabel('time')
# ax3.set_ylabel('amplitude')
# cb3 = fig.colorbar(quad2,ax=ax3)

############################
# ax4 = plt.subplot(gs[:,1])
# line2, = ax4.plot(v,tt,'b',linewidth=2)
# ax4.set_xlim(-10,10)
# ax4.set_ylim(0,1)

def init():
    line.set_data([],[])
    line2.set_data([],[])
    quad1.set_array([])
    return line,line2,quad1

def animate(iter):
    t = np.sin(2*v-iter/(2*np.pi))*np.sin(2*v-iter/(2*np.pi))
    tt = np.cos(2*v-iter/(2*np.pi))*np.cos(2*v-iter/(2*np.pi))
    z = np.sin(x-iter/(2*np.pi))*np.sin(x-iter/(2*np.pi))+np.sin(y)*np.sin(y)
    line.set_data(v,t)
    quad1.set_array(z.ravel())
    line2.set_data(v,tt)
    return line,line2,quad1

gs.tight_layout(fig)

anim = animation.FuncAnimation(fig,animate,frames=100,interval=50,blit=False,repeat=False)
anim.save('test.gif', writer='imagemagick')

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
import matplotlib.animation as animation

y, x = np.meshgrid(np.linspace(-10, 10,100), np.linspace(-10, 10,100))

z = np.sin(x)*np.sin(x)+np.sin(y)*np.sin(y)

v = np.linspace(-10, 10,100)
t = np.sin(v)*np.sin(v)
tt = np.cos(v)*np.cos(v)
###########

fig = plt.figure(figsize=(16, 8),facecolor='white')
gs = gridspec.GridSpec(1, 1)

#########################
# #############################
ax2 = plt.subplot(gs[0])
quad1 = ax2.pcolormesh(x,y,z,shading='gouraud')
ax2.set_xlabel('time')
ax2.set_ylabel('amplitude')
cb2 = fig.colorbar(quad1,ax=ax2)

def init():
    quad1.set_array([])
    return line,line2,quad1

def animate(iter):
    t = np.sin(2*v-iter/(2*np.pi))*np.sin(2*v-iter/(2*np.pi))
    tt = np.cos(2*v-iter/(2*np.pi))*np.cos(2*v-iter/(2*np.pi))
    z = np.sin(x-iter/(2*np.pi))*np.sin(x-iter/(2*np.pi))+np.sin(y)*np.sin(y)
    quad1.set_array(z.ravel())
    return quad1

gs.tight_layout(fig)

anim = animation.FuncAnimation(fig,animate,frames=100,interval=50,blit=False,repeat=False)
anim.save('test2.gif', writer='imagemagick')

# %%
d1
# Out:
# <xarray.DataArray 'ts' (time: 612, lat: 90, lon: 144)>
# array([[[243.3004 , 243.3004 , ..., 243.3004 , 243.3004 ],
#         [244.96667, 244.77176, ..., 245.31703, 244.97905],
#         ...,
#         [236.44856, 236.63518, ..., 236.35323, 236.42053],
#         [235.57591, 235.57591, ..., 235.57591, 235.57591]],
#
#        [[238.67554, 238.67554, ..., 238.67554, 238.67554],
#         [238.95854, 239.00229, ..., 239.00793, 238.84596],
#         ...,
#         [235.8761 , 235.94049, ..., 235.68698, 235.37889],
#         [233.98311, 233.98311, ..., 233.98311, 233.98311]],
#
#        ...,
#
#        [[240.12251, 240.12251, ..., 240.12251, 240.12251],
#         [241.03421, 240.73232, ..., 241.47285, 241.08647],
#         ...,
#         [254.72588, 254.79758, ..., 255.0225 , 254.90642],
#         [255.35927, 255.35927, ..., 255.35927, 255.35927]],
#
#        [[252.28381, 252.28381, ..., 252.28381, 252.28381],
#         [252.95267, 252.7722 , ..., 253.18568, 252.94403],
#         ...,
#         [250.62883, 250.89798, ..., 250.95193, 250.99716],
#         [249.85435, 249.85435, ..., 249.85435, 249.85435]]], dtype=float32)
# Coordinates:
#   * time     (time) object 1850-01-16 12:00:00 ... 1900-12-16 12:00:00
#   * lat      (lat) float64 -89.0 -87.0 -85.0 -83.0 -81.0 ... 83.0 85.0 87.0 89.0
#   * lon      (lon) float64 1.25 3.75 6.25 8.75 11.25 ... 351.2 353.8 356.2 358.8
# Attributes:
#     standard_name:  surface_temperature
#     long_name:      Surface Temperature
#     comment:        Temperature of the lower boundary of the atmosphere
#     units:          K
#     cell_methods:   area: time: mean
#     cell_measures:  area: areacella
#     history:        2019-08-19T19:40:51Z altered by CMOR: replaced missing va...

# %%
quad1.set_array(z.ravel())

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
import matplotlib.animation as animation

x,y = np.meshgrid(d1.lon.values, d1.lat.values)
z = d1.isel(time = 0).values

t = d1.time.values
###########

fig = plt.figure(figsize=(16, 8),facecolor='white')
gs = gridspec.GridSpec(1, 1)

#########################
# #############################
ax2 = plt.subplot(gs[0])
quad1 = ax2.pcolormesh(x,y,z,shading='gouraud')
ax2.set_xlabel('time')
ax2.set_ylabel('amplitude')
cb2 = fig.colorbar(quad1,ax=ax2)

def init():
    quad1.set_array([])
    return quad1

def animate(time):
    z = d1.isel(time = time).values
    quad1.set_array(z.ravel())
    ax.set_title(str(time))
    return quad1

gs.tight_layout(fig)

anim = animation.FuncAnimation(fig,animate,frames=len(t),interval=100,blit=False,repeat=True)
anim.save('test3.gif', writer='imagemagick')
