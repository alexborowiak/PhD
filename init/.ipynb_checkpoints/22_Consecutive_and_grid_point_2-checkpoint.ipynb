# %% [markdown]
# # S/N and Exceedance

# %%
import numpy as np
import pandas as pd
import itertools
import xarray as xr
import os
from dask.diagnostics import ProgressBar
import sys
import signal_to_noise as sn
from importlib import reload
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import cftime

# %%
ROOT_DIR = '/g/data/w40/ab2313/longrunmip'

# %%
os.listdir(ROOT_DIR)
# Out:
# ['tas_ann_ECHAM5MPIOM_1pct4x_6080.nc',
#  'tas_mon_CCSM3_control_1530.nc',
#  'tas_mon_MIROC32_control_681.nc',
#  'tas_mon_CCSM3_abrupt4x_2120.nc',
#  'tas_ann_FAMOUS_abrupt4x_3000_g025.nc',
#  'tas_ann_ECHAM5MPIOM_control_100.nc',
#  'tas_mon_MIROC32_abrupt4x_150.nc',
#  'tas_mon_CCSM3_abrupt2x_3000.nc',
#  'tas_mon_CCSM3_abrupt8x_1450.nc',
#  'tas_mon_MIROC32_1pct4x_2002.nc',
#  'tas_mon_MIROC32_1pct2x_2003.nc']

# %% [markdown]
# # piControl

# %%
control = xr.open_dataset(f'{ROOT_DIR}/tas_mon_CCSM3_control_1530.nc',
                             use_cftime = True, chunks = {'lat':48/2,'lon':96/2,'time':-1})

# %%
control.tas

# %%
control = control.resample(time = 'Y').mean(dim = 'time')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-492-700e041e3884> in <module>
# ----> 1 control = control.resample(time = 'Y').mean(dim = 'time')
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/core/common.py in wrapped_func(self, dim, skipna, **kwargs)
#      91
#      92             def wrapped_func(self, dim=None, skipna=None, **kwargs):
# ---> 93                 return self.reduce(
#      94                     func, dim, skipna=skipna, numeric_only=numeric_only, **kwargs
#      95                 )
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/core/resample.py in reduce(self, func, dim, keep_attrs, **kwargs)
#     341             removed.
#     342         """
# --> 343         return super().reduce(func, dim, keep_attrs, **kwargs)
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/core/groupby.py in reduce(self, func, dim, keep_attrs, **kwargs)
#     985         check_reduce_dims(dim, self.dims)
#     986
# --> 987         return self.map(reduce_dataset)
#     988
#     989     def assign(self, **kwargs):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/core/resample.py in map(self, func, args, shortcut, **kwargs)
#     296         # ignore shortcut if set (for now)
#     297         applied = (func(ds, *args, **kwargs) for ds in self._iter_grouped())
# --> 298         combined = self._combine(applied)
#     299
#     300         return combined.rename({self._resample_dim: self._dim})
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/core/groupby.py in _combine(self, applied)
#     936         applied_example, applied = peek_at(applied)
#     937         coord, dim, positions = self._infer_concat_args(applied_example)
# --> 938         combined = concat(applied, dim)
#     939         combined = _maybe_reorder(combined, dim, positions)
#     940         # assign coord when the applied function does not return that coord
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/core/concat.py in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     236             f"objects, got {type(first_obj)}"
#     237         )
# --> 238     return f(
#     239         objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs
#     240     )
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/core/concat.py in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     506             except KeyError:
#     507                 raise ValueError(f"{k!r} is not present in all datasets.")
# --> 508             combined = concat_vars(vars, dim, positions, combine_attrs=combine_attrs)
#     509             assert isinstance(combined, Variable)
#     510             result_vars[k] = combined
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/core/variable.py in concat(variables, dim, positions, shortcut, combine_attrs)
#    2860         return IndexVariable.concat(variables, dim, positions, shortcut, combine_attrs)
#    2861     else:
# -> 2862         return Variable.concat(variables, dim, positions, shortcut, combine_attrs)
#    2863
#    2864
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/core/variable.py in concat(cls, variables, dim, positions, shortcut, combine_attrs)
#    1819             axis = first_var.get_axis_num(dim)
#    1820             dims = first_var.dims
# -> 1821             data = duck_array_ops.concatenate(arrays, axis=axis)
#    1822             if positions is not None:
#    1823                 # TODO: deprecate this option -- we don't need it for groupby
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/core/duck_array_ops.py in concatenate(arrays, axis)
#     310 def concatenate(arrays, axis=0):
#     311     """concatenate() with better dtype promotion rules."""
# --> 312     return _concatenate(as_shared_dtype(arrays), axis=axis)
#     313
#     314
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/core/duck_array_ops.py in f(*args, **kwargs)
#      54             else:
#      55                 wrapped = getattr(eager_module, name)
# ---> 56             return wrapped(*args, **kwargs)
#      57
#      58     else:
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/dask/array/core.py in concatenate(seq, axis, allow_unknown_chunksizes)
#    3882         type(max(seq_metas, key=lambda x: getattr(x, "__array_priority__", 0)))
#    3883     )
# -> 3884     meta = _concatenate(seq_metas, axis=axis)
#    3885
#    3886     # Promote types to match meta
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
control_climatology = sn.climatology(control, 
                                         start = control.time.dt.year.values[0]
                                        ,end = control.time.dt.year.values[-1])

# %%
control_climatology

# %%
control_anomaly = control - control_climatology

# %%
control_anomaly
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 48, lon: 96, time: 1531)
# Coordinates:
#   * time     (time) object 0001-12-31 00:00:00 ... 1531-12-31 00:00:00
#   * lat      (lat) float64 -87.16 -83.48 -79.78 -76.07 ... 79.78 83.48 87.16
#   * lon      (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2
# Data variables:
#     tas      (time, lat, lon) float32 dask.array<chunksize=(1, 48, 96), meta=np.ndarray>

# %%
control_anomaly_smean = sn.space_mean(control_anomaly)

# %% [markdown]
# ## SN Control
# The signal to noist of the control. his defines the bounds of what is considered unstable and what is not unstable.

# %%
reload(sn)
# Out:
# <module 'signal_to_noise' from '/home/563/ab2313/Documents/PhD/init/signal_to_noise.py'>

# %%
control_anomaly_smean = control_anomaly_smean.load()

# %%
control_sn = (sn.sn_grad_loess_grid(control_anomaly_smean)).squeeze()

# %%
control_sn.plot()

# %%
fig = plt.figure(figsize=  (15,10))
ax = fig.add_subplot(111)

time =  control_sn.time.values

ax.plot(time,control_sn, label = 'S/N', c = 'darkred')

c0 = plt.gca().lines[0].get_color()
ax.tick_params(axis = 'y', labelcolor = c0)
ax.set_ylabel('Signal\n----------\nNoise', fontsize = 12, color = c0, rotation = 0, labelpad = 55);

leg = ax.legend(ncol = 1, fontsize = 12, bbox_to_anchor = [1.16, 1])
leg.set_title('Noise Type')
leg.get_title().set_fontsize('12')

ax.yaxis.set_major_locator(mticker.MultipleLocator(.5))
ax.yaxis.set_minor_locator(mticker.MultipleLocator(.25))

# Second y-axis: the temperature anomalies.
ax2 = ax.twinx()

ax2.plot(control_anomaly_smean.time.values, control_anomaly_smean.tas.values,
         color = 'green', alpha = 0.4, label  = 'Temp Anomaly')

c1 = plt.gca().lines[0].get_color()
ax2.tick_params(axis = 'y', labelcolor = c1)
ax2.spines['right'].set_color(c1)
ax2.spines['left'].set_color(c0)
ax2.set_ylabel('Tempearture\nAnomaly', fontsize = 12, color = c1, rotation = 0, labelpad = 55);
ax2.yaxis.set_major_locator(mticker.MultipleLocator(.5))
ax2.yaxis.set_minor_locator(mticker.MultipleLocator(.25))

ax2.set_xlim([time[0], time[-1]])
ax.set_xlabel('Year', fontsize = 12);
ax.set_xlim(control_anomaly_smean.time.values[0], control_anomaly_smean.time.values[-1])
# ax.grid(which = 'major', axis = 'both', linestyle = ':', alpha = 0.5, zorder = -100)

# ax.set_title(f'BEST Signal/Noise and Temperature Anomaly ({ROLL_PERIOD/MONTHS_IN_YEAR}Y Window)', size = 15)
# Out:
# (-729271.0, -170821.0)

# %%
# The stable bound is the bound where anything that exceeds this will be considered unstable.
stable_bound_max = np.nanmax(control_sn)
stable_bound = np.nanpercentile(control_sn, q = 90)
stable_bound
# Out:
# 0.9222583469551268

# %%
print(stable_bound, stable_bound_max)
# Out:
# 0.9222583469551268 1.8297087178251428

# %% [markdown]
# ### Signal to Noise for Each grid cell

# %%
control_anomaly = control_anomaly.chunk({'time':-1})

# %%
control_anomaly.tas

# %%
# %%time
control_sn_grid = sn.sn_grad_loess_grid(control_anomaly)
# Out:
# [########################################] | 100% Completed |  9.8s

# %%
control_sn_grid
# Out:
# <xarray.DataArray 'S/N' (time: 1473, lat: 48, lon: 96)>
# dask.array<getitem, shape=(1473, 48, 96), dtype=float64, chunksize=(60, 48, 96), chunktype=numpy.ndarray>
# Coordinates:
#   * time      (time) object 0001-12-31 00:00:00 ... 1473-12-31 00:00:00
#   * lat       (lat) float64 -87.16 -83.48 -79.78 -76.07 ... 79.78 83.48 87.16
#   * lon       (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2
#     variable  <U3 'tas'

# %%
control_sn_grid.sel(lat = -38, lon = 142.5, method = 'nearest').plot()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-465-7c2623790eb2> in <module>
# ----> 1 control_sn_grid.sel(lat = -38, lon = 142.5, method = 'nearest').plot()
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/plot/plot.py in __call__(self, **kwargs)
#     450
#     451     def __call__(self, **kwargs):
# --> 452         return plot(self._da, **kwargs)
#     453
#     454     # we can't use functools.wraps here since that also modifies the name / qualname
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/plot/plot.py in plot(darray, row, col, col_wrap, ax, hue, rtol, subplot_kws, **kwargs)
#     164     xarray.DataArray.squeeze
#     165     """
# --> 166     darray = darray.squeeze().compute()
#     167
#     168     plot_dims = set(darray.dims)
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/core/dataarray.py in compute(self, **kwargs)
#     909         """
#     910         new = self.copy(deep=False)
# --> 911         return new.load(**kwargs)
#     912
#     913     def persist(self, **kwargs) -> "DataArray":
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/core/dataarray.py in load(self, **kwargs)
#     883         dask.compute
#     884         """
# --> 885         ds = self._to_temp_dataset().load(**kwargs)
#     886         new = self._from_temp_dataset(ds)
#     887         self._variable = new._variable
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/xarray/core/dataset.py in load(self, **kwargs)
#     848
#     849             # evaluate all the dask arrays simultaneously
# --> 850             evaluated_data = da.compute(*lazy_data.values(), **kwargs)
#     851
#     852             for k, data in zip(lazy_data, evaluated_data):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     565         postcomputes.append(x.__dask_postcompute__())
#     566
# --> 567     results = schedule(dsk, keys, **kwargs)
#     568     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     569
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      77             pool = MultiprocessingPoolExecutor(pool)
#      78
# ---> 79     results = get_async(
#      80         pool.submit,
#      81         pool._max_workers,
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/dask/local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     501             while state["waiting"] or state["ready"] or state["running"]:
#     502                 fire_tasks(chunksize)
# --> 503                 for key, res_info, failed in queue_get(queue).result():
#     504                     if failed:
#     505                         exc, tb = loads(res_info)
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/dask/local.py in queue_get(q)
#     132
#     133     def queue_get(q):
# --> 134         return q.get()
#     135
#     136
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/queue.py in get(self, block, timeout)
#     168             elif timeout is None:
#     169                 while not self._qsize():
# --> 170                     self.not_empty.wait()
#     171             elif timeout < 0:
#     172                 raise ValueError("'timeout' must be a non-negative number")
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %% [markdown]
# # SN 4xCO2

# %%
os.listdir(ROOT_DIR)
# Out:
# ['tas_ann_ECHAM5MPIOM_1pct4x_6080.nc',
#  'tas_mon_CCSM3_control_1530.nc',
#  'tas_mon_MIROC32_control_681.nc',
#  'tas_mon_CCSM3_abrupt4x_2120.nc',
#  'tas_ann_FAMOUS_abrupt4x_3000_g025.nc',
#  'tas_ann_ECHAM5MPIOM_control_100.nc',
#  'tas_mon_MIROC32_abrupt4x_150.nc',
#  'tas_mon_CCSM3_abrupt2x_3000.nc',
#  'tas_mon_CCSM3_abrupt8x_1450.nc',
#  'tas_mon_MIROC32_1pct4x_2002.nc',
#  'tas_mon_MIROC32_1pct2x_2003.nc']

# %%
quadco2 = xr.open_dataset(f'{ROOT_DIR}/tas_mon_CCSM3_abrupt4x_2120.nc',
                             use_cftime = True, chunks = {'lat':100,'lon':100})

# %% [markdown]
# ### Fixing Bugged Time
# In then time there is a year where there is a repeated timestep and one missing. To fix this just regenerate the time using the xt.cftimerange to generate time between the start and the end.

# %%
fixed_time = xr.cftime_range(start = quadco2.time.values[0], 
                            end = quadco2.time.values[-1] + pd.to_timedelta('32D')
                            ,freq = '1M'
               )

# %%
fixed_time[:5]
# Out:
# CFTimeIndex([0001-02-28 00:00:00, 0001-03-31 00:00:00, 0001-04-30 00:00:00,
#              0001-05-31 00:00:00, 0001-06-30 00:00:00],
#             dtype='object', length=5, calendar='noleap', freq='M')

# %%
len(fixed_time)
# Out:
# 25440

# %%
len(quadco2.time.values)
# Out:
# 25440

# %%
quadco2['time'] = fixed_time

# %%
quadco2_yearmean = quadco2.resample(time = 'Y').mean(dim = 'time')
quadco2_yearmean
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 48, lon: 96, time: 2121)
# Coordinates:
#   * time     (time) object 0001-12-31 00:00:00 ... 2121-12-31 00:00:00
#   * lat      (lat) float64 -87.16 -83.48 -79.78 -76.07 ... 79.78 83.48 87.16
#   * lon      (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2
# Data variables:
#     tas      (time, lat, lon) float32 dask.array<chunksize=(1, 48, 96), meta=np.ndarray>

# %%
quadco2.sel(lat = -38, lon = 144, method = 'nearest').tas.plot()
quadco2_yearmean.sel(lat = -38, lon = 144, method = 'nearest').tas.plot()

# %% [markdown]
# # Global Mean

# %% [markdown]
# ## Anomlies

# %%
quadco2_anom = (quadco2_yearmean - control_climatology).to_array()

# %%
quadco2_anom_smean = sn.space_mean(quadco2_anom).squeeze()

# %%
plt.plot(quadco2_anom_smean.values)

# %% [markdown]
# ## Singal to Noise

# %%
quadco2_anom_smean = quadco2_anom_smean.load()

# %%
roll_period = 101#61

# %%
quad_sn, signal, noise, loess, loess_detrend = sn.sn_grad_loess_grid(quadco2_anom_smean, 
                                                                roll_period = roll_period, unit  = 'Y',
                                                                return_all = 1)

# %%
quad_sn
# Out:
# <xarray.DataArray 'S/N' (time: 2021)>
# array([10.28172188, 10.62824702, 10.5014414 , ..., -1.09636797,
#        -1.11706255, -1.13042097])
# Coordinates:
#   * time      (time) object 0001-12-31 00:00:00 ... 2021-12-31 00:00:00
#     variable  <U3 'tas'

# %% [markdown]
# ## Exceenance Instance
# This is where the model run is condidsered unstable.

# %%
reload(sn)
# Out:
# <module 'signal_to_noise' from '/home/563/ab2313/Documents/PhD/init/signal_to_noise.py'>

# %%
consec_start_arg, consec_len = sn.consecutive_counter(quad_sn.values > stable_bound)

# %%
 consec_len[:5]
# Out:
# array([127,   3,   3,  61, 272])

# %%
consec_len = consec_len + roll_period

# %%
 consec_len[:5]
# Out:
# array([228, 104, 104, 162, 373])

# %%
consec_start_arg[:5]
# Out:
# array([  0, 176, 180, 199, 301])

# %%
trend_args = []

for se_args in np.dstack([consec_start_arg, consec_len])[0]:
    trend_args.append(np.arange(se_args[0], se_args[0] + se_args[-1]))

# %%
trend_args = np.unique([t for t_list in trend_args for t in t_list])
trend_args
# Out:
# array([   0,    1,    2, ..., 2094, 2095, 2096])

# %%
len(trend_args)
# Out:
# 1834

# %%
len(quad_sn.time.values)
# Out:
# 2021

# %%
# Using list comprehension to turn the arguements into time values. 
consec_start = [quad_sn.time.values[arg] for arg in consec_start_arg]
consec_start[:5]
# Out:
# [cftime.DatetimeNoLeap(1, 12, 31, 0, 0, 0, 0),
#  cftime.DatetimeNoLeap(177, 12, 31, 0, 0, 0, 0),
#  cftime.DatetimeNoLeap(181, 12, 31, 0, 0, 0, 0),
#  cftime.DatetimeNoLeap(200, 12, 31, 0, 0, 0, 0),
#  cftime.DatetimeNoLeap(302, 12, 31, 0, 0, 0, 0)]

# %%
# %%time
for i in range(1000):
    _,_ = return_consecutive_groups(data,stable_bound)
# Out:
# CPU times: user 263 ms, sys: 17.2 ms, total: 280 ms
# Wall time: 271 ms

# %%
quad_sn.where(quad_sn > stable_bound).plot()

# %%
fig = plt.figure(figsize=  (15,10))
ax = fig.add_subplot(111)

time =  quad_sn.time.values

ax.plot(time, quad_sn, label = 'S/N', c = 'darkred', zorder = 100000)

c0 = plt.gca().lines[0].get_color()
ax.tick_params(axis = 'y', labelcolor = c0)
ax.set_ylabel('Signal\n----------\nNoise', fontsize = 12, color = c0, rotation = 0, labelpad = 55);

leg = ax.legend(ncol = 1, fontsize = 12, bbox_to_anchor = [1.16, 1])
leg.set_title('Noise Type')
leg.get_title().set_fontsize('12')

ax.yaxis.set_major_locator(mticker.MultipleLocator(.5))
ax.yaxis.set_minor_locator(mticker.MultipleLocator(.25))

# Second y-axis: the temperature anomalies.
ax2 = ax.twinx()

ax2.plot(quadco2_anom_smean.time.values, quadco2_anom_smean.values,
         color = 'green', alpha = 0.4, label  = 'Temp Anomaly')

ax2.plot(
    quadco2_anom_smean.where(quad_sn > stable_bound).time.values,
    quadco2_anom_smean.where(quad_sn > stable_bound).values, color = 'darkgreen',
    alpha = 0.8
    )


for start in consec_start:
    ax2.scatter(start, quadco2_anom_smean.sel(time = start).values,color = 'k')

c1 = plt.gca().lines[0].get_color()
ax2.tick_params(axis = 'y', labelcolor = c1)
ax2.spines['right'].set_color(c1)
ax2.spines['left'].set_color(c0)
ax.spines['right'].set_color(c1)
ax.spines['left'].set_color(c0)


ax2.set_ylabel('Tempearture\nAnomaly', fontsize = 12, color = c1, rotation = 0, labelpad = 55);
ax2.yaxis.set_major_locator(mticker.MultipleLocator(.5))
ax2.yaxis.set_minor_locator(mticker.MultipleLocator(.25))

ax2.set_xlim([time[0] - pd.to_timedelta('30Y'), time[-1]])

ax.set_xlabel('Year', fontsize = 12);

ax.plot([time[0], time[-1]],[stable_bound, stable_bound], color = 'k', linestyle = ':', alpha = 0.65)

ANNOTATE_X = -200
ax.annotate('Unstable', xy = (time[ANNOTATE_X], stable_bound + 0.1), ha = 'left');
ax_ylim = ax.get_ylim()
ax.plot([time[5], time[roll_period + 5]], [ax_ylim[0] - 0.4, ax_ylim[0] -0.4], linestyle = ':')

# ax.grid(which = 'major', axis = 'both', linestyle = ':', alpha = 0.5, zorder = -100)
# ax.set_title(f'BEST Signal/Noise and Temperature Anomaly ({ROLL_PERIOD/MONTHS_IN_YEAR}Y Window)', size = 15
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/pandas/core/tools/timedeltas.py:132: FutureWarning: Units 'M', 'Y' and 'y' do not represent unambiguous timedelta values and will be removed in a future version
#   return _coerce_scalar_to_timedelta_type(arg, unit=unit, errors=errors)

# %%
quadco2_anom_smean
# Out:
# <xarray.DataArray 'stack-9ed34464fdf6c7f567c67dbb4f1045ba' (time: 2121)>
# array([2.34939426, 2.57499968, 2.74476572, ..., 5.06528311, 5.02304883,
#        3.83989798])
# Coordinates:
#   * time      (time) object 0001-12-31 00:00:00 ... 2121-12-31 00:00:00
#     variable  <U3 'tas'

# %%
trend_args[:5]
# Out:
# array([0, 1, 2, 3, 4])

# %%
trend_time = [quadco2_anom_smean.time.values[arg] for arg in trend_args]
trend_time[:5]
# Out:
# [cftime.DatetimeNoLeap(1, 12, 31, 0, 0, 0, 0),
#  cftime.DatetimeNoLeap(2, 12, 31, 0, 0, 0, 0),
#  cftime.DatetimeNoLeap(3, 12, 31, 0, 0, 0, 0),
#  cftime.DatetimeNoLeap(4, 12, 31, 0, 0, 0, 0),
#  cftime.DatetimeNoLeap(5, 12, 31, 0, 0, 0, 0)]

# %%
trend_points = quadco2_anom_smean.where(quadco2_anom_smean.time.isin(trend_time))

# %%
trend_points.plot()

# %%
fig = plt.figure(figsize=  (15,10))
ax = fig.add_subplot(111)

time =  quad_sn.time.values

ax.plot(time, quad_sn, label = 'S/N', c = 'darkred', zorder = 100000)

c0 = plt.gca().lines[0].get_color()
ax.tick_params(axis = 'y', labelcolor = c0)
ax.set_ylabel('Signal\n----------\nNoise', fontsize = 12, color = c0, rotation = 0, labelpad = 55);



ax.yaxis.set_major_locator(mticker.MultipleLocator(.5))
ax.yaxis.set_minor_locator(mticker.MultipleLocator(.25))

# Second y-axis: the temperature anomalies.
ax2 = ax.twinx()

ax2.plot(quadco2_anom_smean.time.values, quadco2_anom_smean.values,
         color = 'green', alpha = 0.4, label  = 'Stable')

# ax2.plot(
#     quadco2_anom_smean.where(quad_sn > stable_bound).time.values,
#     quadco2_anom_smean.where(quad_sn > stable_bound).values, color = 'darkgreen',
#     alpha = 0.8
#     )

ax2.plot(trend_points.time.values, trend_points.values, color = 'darkgreen',
     alpha = 0.8, label = 'Unstable')

leg = ax2.legend(ncol = 1, fontsize = 12, bbox_to_anchor = [1.16, 1])
leg.set_title('Temperature Stabillity')
leg.get_title().set_fontsize('12')

c1 = plt.gca().lines[0].get_color()
ax2.tick_params(axis = 'y', labelcolor = c1)
ax2.spines['right'].set_color(c1)
ax2.spines['left'].set_color(c0)
ax.spines['right'].set_color(c1)
ax.spines['left'].set_color(c0)


ax2.set_ylabel('Tempearture\nAnomaly', fontsize = 12, color = c1, rotation = 0, labelpad = 55);
ax2.yaxis.set_major_locator(mticker.MultipleLocator(.5))
ax2.yaxis.set_minor_locator(mticker.MultipleLocator(.25))

ax2.set_xlim([time[0] - pd.to_timedelta('30Y'), time[-1]])

ax.set_xlabel('Year', fontsize = 12);

ax.plot([time[0], time[-1]],[stable_bound, stable_bound], color = 'k', linestyle = ':', alpha = 0.65)

ANNOTATE_X = -200
ax.annotate('Unstable', xy = (time[ANNOTATE_X], stable_bound + 0.1), ha = 'left');
ax_ylim = ax.get_ylim()
ax.plot([time[5], time[roll_period + 5]], [ax_ylim[0] - 0.4, ax_ylim[0] -0.4], linestyle = ':')
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/pandas/core/tools/timedeltas.py:132: FutureWarning: Units 'M', 'Y' and 'y' do not represent unambiguous timedelta values and will be removed in a future version
#   return _coerce_scalar_to_timedelta_type(arg, unit=unit, errors=errors)

# %% [markdown]
# # Applying to Multiple GridCells

# %%
quadco2_anom = quadco2_anom.squeeze()

# %%
quadco2_anom
# Out:
# <xarray.DataArray 'stack-9ed34464fdf6c7f567c67dbb4f1045ba' (time: 2121, lat: 48, lon: 96)>
# dask.array<getitem, shape=(2121, 48, 96), dtype=float32, chunksize=(1, 48, 96), chunktype=numpy.ndarray>
# Coordinates:
#   * time      (time) object 0001-12-31 00:00:00 ... 2121-12-31 00:00:00
#   * lat       (lat) float64 -87.16 -83.48 -79.78 -76.07 ... 79.78 83.48 87.16
#   * lon       (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2
#     variable  <U3 'tas'

# %%
quadco2_anom = quadco2_anom.chunk({'time':120})

# %%
quadco2_anom
# Out:
# <xarray.DataArray 'stack-9ed34464fdf6c7f567c67dbb4f1045ba' (time: 2121, lat: 48, lon: 96)>
# dask.array<rechunk-merge, shape=(2121, 48, 96), dtype=float32, chunksize=(120, 48, 96), chunktype=numpy.ndarray>
# Coordinates:
#   * time      (time) object 0001-12-31 00:00:00 ... 2121-12-31 00:00:00
#   * lat       (lat) float64 -87.16 -83.48 -79.78 -76.07 ... 79.78 83.48 87.16
#   * lon       (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2
#     variable  <U3 'tas'

# %%
test_data = quadco2_anom.sel(lat = slice(-40,-25), lon = slice(140,155))
test_data
# Out:
# <xarray.DataArray 'stack-9ed34464fdf6c7f567c67dbb4f1045ba' (time: 2121, lat: 4, lon: 4)>
# dask.array<getitem, shape=(2121, 4, 4), dtype=float32, chunksize=(120, 4, 4), chunktype=numpy.ndarray>
# Coordinates:
#   * time      (time) object 0001-12-31 00:00:00 ... 2121-12-31 00:00:00
#   * lat       (lat) float64 -38.97 -35.26 -31.54 -27.83
#   * lon       (lon) float64 142.5 146.2 150.0 153.8
#     variable  <U3 'tas'

# %%
sn_grid, signal_grid, noise_grid, loess_grid, loess_detrend_grid = sn.sn_grad_loess_grid(test_data, return_all = 1)

# %%
sn_grid.sel(lat = -38, lon = 142.5, method = 'nearest').plot()
