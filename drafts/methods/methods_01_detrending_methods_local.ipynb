# %% [markdown]
# # Methods of De-treding
# This notebook outllines different methods that can be used to de-trend the LongRunMIP and ZECMIP time series.

# %%
import nc_time_axis
import warnings

import xarray as xr
import numpy as np
import pandas as pd
from importlib import reload
import string


import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker as mticker
import matplotlib.gridspec as gridspec 
from matplotlib.axes import Axes
from matplotlib.colors import ListedColormap
import matplotlib.cm as cm

import os
import sys

from numpy.typing import ArrayLike
from typing import Optional, Callable, List, Tuple, Dict

warnings.filterwarnings('ignore')

# %%
import constants
sys.path.append(constants.MODULE_DIR)
import sn_plotting as sn_plot
import xarray_class_accessors as xca
import utils
import stats
import xarray_extender as xce
import signal_to_noise as sn
import open_ds
from classes import ExperimentTypes, LocationsLatLon

logger = utils.get_notebook_logger()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import constants
# ----> 2 sys.path.append(constants.MODULE_DIR)
#       3 import sn_plotting as sn_plot
#       4 import xarray_class_accessors as xca
#
# NameError: name 'sys' is not defined

# %%
notebook_number='01'

# %%
import dask.distributed as dd
import tempfile

tempdir = tempfile.TemporaryDirectory("dask-worker-space")
dd.Client(local_directory=tempdir.name, memory_limit='16gb')
# Out:
# <Client: 'tcp://127.0.0.1:39981' processes=4 threads=16, memory=59.60 GiB>

# %% [markdown]
# # Loading Data

# %%
experiment_params = constants.EXPERIMENTS_TO_RUN[0]

# %% [markdown]
# ## ZECMIP

# %%
experiment_zec_ds = xr.open_mfdataset(os.path.join(
    constants.ZECMIP_LOCAL_DIR, 'regridded', '4xCO2', '*.nc')).compute()

picontrol_zec_ds = xr.open_mfdataset(
    os.path.join(constants.ZECMIP_LOCAL_DIR, 'regridded', 'picontrol', '*.nc'), 
                  use_cftime=True, concat_dim='model', combine='nested').compute()
experiment_zec_ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 330, lat: 96, lon: 192, model: 8)
# Coordinates:
#   * time     (time) object 0001-12-31 00:00:00 ... 0330-12-31 00:00:00
#   * lat      (lat) float64 -88.57 -86.72 -84.86 -83.0 ... 83.0 84.86 86.72 88.57
#   * lon      (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
#   * model    (model) object 'CESM2' 'CanESM5' ... 'NorESM2-LM' 'UKESM1-0-LL'
#     height   float64 2.0
# Data variables:
#     tas      (time, model, lat, lon) float32 228.2 228.1 228.0 ... 265.1 265.1

# %%
experiment_zec_ds_smean, picontrol_zec_ds_smean = sn.calculate_global_value(
    experiment_zec_ds, picontrol_zec_ds,experiment_params["variable"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 experiment_zec_ds_smean, picontrol_zec_ds_smean = sn.calculate_global_value(
#       2     experiment_zec_ds, picontrol_zec_ds,experiment_params["variable"])
#
# NameError: name 'sn' is not defined

# %% [markdown]
# ## Abrupt 4x

# %%
reload(open_ds)
# Out:
# <module 'open_ds' from '/home/563/ab2313/Documents/PhD/modules/open_ds.py'>

# %%
control_abrupt_ds = open_ds.open_experiment_files(experiment_params, ExperimentTypes.CONTROL)
abrupt4x_ds = open_ds.open_experiment_files(experiment_params, ExperimentTypes.ABRUPT4X)
# Out:
# - /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped=
# - Opening files in /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped
# - Time lengths
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_CCSM3_control_1530_g025.nc
# - requested_length=100
# - Removing first 10 steps
# - Rename var='tas' to ccsm3
# - Converting from Kelvin to C
# - tas_mon_CCSM3_control_1530_g025.nc - 1520
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_CESM104_control_1000_g025.nc
# - requested_length=100
# - Rename var='tas' to cesm104
# - Converting from Kelvin to C
# - tas_mon_CESM104_control_1000_g025.nc - 1000
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_CNRMCM61_control_2000_g025.nc
# - requested_length=100
# - Rename var='tas' to cnrmcm61
# - Converting from Kelvin to C
# - tas_mon_CNRMCM61_control_2000_g025.nc - 2000
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_HadCM3L_control_1000_g025.nc
# - requested_length=100
# - Rename var='tas' to hadcm3l
# - Converting from Kelvin to C
# - tas_mon_HadCM3L_control_1000_g025.nc - 1000
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_IPSLCM5A_control_1000_g025.nc
# - requested_length=100
# - Rename var='tas' to ipslcm5a
# - Converting from Kelvin to C
# - tas_mon_IPSLCM5A_control_1000_g025.nc - 1000
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_ann_MPIESM11_control_2000_g025.nc
# - requested_length=100
# - Rename var='tas' to mpiesm11
# - Converting from Kelvin to C
# - tas_ann_MPIESM11_control_2000_g025.nc - 2000
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_MPIESM12_control_1237_g025.nc
# - requested_length=100
# - Rename var='tas' to mpiesm12
# - Converting from Kelvin to C
# - tas_mon_MPIESM12_control_1237_g025.nc - 1237
# - Time length with all models present 1000
# - Length of final dataset 1000Dataset has coords ['time', 'lon', 'lat', 'height'])Dataset has data vars ['ccsm3', 'cesm104', 'cnrmcm61', 'hadcm3l', 'ipslcm5a', 'mpiesm11', 'mpiesm12']
#
#
# - /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped=
# - Opening files in /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped
# - Time lengths
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_CCSM3_abrupt4x_2120_g025.nc
# - requested_length=800
# - Rename var='tas' to ccsm3
# - Converting from Kelvin to C
# - tas_mon_CCSM3_abrupt4x_2120_g025.nc - 2120
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_CESM104_abrupt4x_5900_g025.nc
# - requested_length=800
# - Rename var='tas' to cesm104
# - Converting from Kelvin to C
# - tas_mon_CESM104_abrupt4x_5900_g025.nc - 5900
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_CNRMCM61_abrupt4x_1850_g025.nc
# - requested_length=800
# - Rename var='tas' to cnrmcm61
# - Converting from Kelvin to C
# - tas_mon_CNRMCM61_abrupt4x_1850_g025.nc - 1850
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_HadCM3L_abrupt4x_1000_g025.nc
# - requested_length=800
# - Rename var='tas' to hadcm3l
# - Converting from Kelvin to C
# - tas_mon_HadCM3L_abrupt4x_1000_g025.nc - 1000
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_IPSLCM5A_abrupt4x_1000_g025.nc
# - requested_length=800
# - Rename var='tas' to ipslcm5a
# - Converting from Kelvin to C
# - tas_mon_IPSLCM5A_abrupt4x_1000_g025.nc - 1000
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_ann_MPIESM11_abrupt4x_4459_g025.nc
# - requested_length=800
# - Rename var='tas' to mpiesm11
# - Converting from Kelvin to C
# - tas_ann_MPIESM11_abrupt4x_4459_g025.nc - 4459
# - Opening files /g/data/w40/ab2313/PhD/longrunmip/tas/regrid_retimestamped/tas_mon_MPIESM12_abrupt4x_999_g025.nc
# - requested_length=800
# - Rename var='tas' to mpiesm12
# - Converting from Kelvin to C
# - tas_mon_MPIESM12_abrupt4x_999_g025.nc - 1000
# - Time length with all models present 1000
# - Length of final dataset 1000Dataset has coords ['time', 'lon', 'lat', 'height'])Dataset has data vars ['ccsm3', 'cesm104', 'cnrmcm61', 'hadcm3l', 'ipslcm5a', 'mpiesm11', 'mpiesm12']

# %%
abrupt4x_ds_smean, control_abrupt_ds_smean = sn.calculate_global_value(
    abrupt4x_ds, control_abrupt_ds, experiment_params["variable"])

abrupt4x_ds_smean
# Out:
# (None, None)
# ccsm3, cesm104, cnrmcm61, hadcm3l, ipslcm5a, mpiesm11, mpiesm12,
# <xarray.Dataset>
# Dimensions:   (time: 1000)
# Coordinates:
#   * time      (time) int64 0 1 2 3 4 5 6 7 8 ... 992 993 994 995 996 997 998 999
#     height    float64 2.0
# Data variables:
#     ccsm3     (time) float32 2.283 2.567 2.735 2.645 ... 4.878 4.824 4.874 4.906
#     cesm104   (time) float32 1.181 1.599 1.98 2.198 ... 6.182 6.254 6.01 5.886
#     cnrmcm61  (time) float32 1.358 2.042 2.641 3.082 ... 8.922 9.039 9.001 8.91
#     hadcm3l   (time) float64 1.69 2.179 2.517 2.854 ... 5.743 5.876 5.928 5.941
#     ipslcm5a  (time) float32 1.275 1.774 2.037 2.391 ... 7.182 7.248 7.28 7.346
#     mpiesm11  (time) float32 0.9944 1.639 2.238 2.499 ... 6.395 6.37 6.212 6.217
#     mpiesm12  (time) float32 1.36 1.987 2.464 2.725 ... 6.239 6.299 6.542 6.449

# %%
fig = plt.figure(figsize=(14,4))
plt.plot(abrupt4x_ds_smean.ccsm3.values)

# %% [markdown]
# # Calculations

# %% [markdown]
# ## Data Selection

# %%
PROFILE_SELECTOR_DICT = {
    'zec': {
        'global': {'pi': picontrol_zec_ds_smean.tas, 'exp': experiment_zec_ds_smean.tas},
        'local': {'pi': picontrol_zec_ds.tas, 'exp': experiment_zec_ds.tas}},
    'abrupt': {
        'global': {'pi': control_abrupt_ds_smean.to_array(dim='model'),
                   'exp': abrupt4x_ds_smean.to_array(dim='model')},
        'local': {'pi': control_abrupt_ds.to_array(dim='model'),
                  'exp': abrupt4x_ds.to_array(dim='model')}}}

# %%
profile = 'abrupt' # abrupt zec
region = 'local' #  global local
model1 = 'ccsm3'
model2 = 'CESM2'

# %%
experiment_da = PROFILE_SELECTOR_DICT[profile][region]['exp']
picontrol_da = PROFILE_SELECTOR_DICT[profile][region]['pi']

# %% [markdown]
# ## Execution

# %%
reload(xca)
reload(sn)
# Out:
# <module 'signal_to_noise' from '/home/563/ab2313/Documents/PhD/modules/signal_to_noise.py'>

# %%
test_da = experiment_da.isel(time=slice(None, 150), lat=slice(0, 10), lon=slice(0,5))
test_pi = picontrol_da.isel(time=slice(None, 150), lat=slice(0, 10), lon=slice(0,5))

# %%
sn_ds1 = sn.calculate_rolling_signal_to_noise(20, test_da,
                                              detrend_kwargs={'method':'polynomial', 'order':4},
                                    logginglevel='DEBUG')
# Out:
# - detrend_kwargs={'method': 'polynomial', 'order': 4}
# - Detrending required
# - Detrending data with {'method': 'polynomial', 'order': 4}
# - method='polynomial'
#  data
#  <xarray.DataArray (model: 7, time: 150, lat: 10, lon: 5)>
# array([[[[-3.64356537e+01, -3.68105774e+01, -3.68124542e+01,
#           -3.71937714e+01, -3.71956482e+01],
#          [-3.58370667e+01, -3.62205505e+01, -3.66047668e+01,
#           -3.69874573e+01, -3.73686218e+01],
#          [-3.43840637e+01, -3.51145782e+01, -3.58551483e+01,
#           -3.65926666e+01, -3.73271027e+01],
#          ...,
#          [-1.85668793e+01, -1.93369598e+01, -1.99259491e+01,
#           -2.05832062e+01, -2.13087311e+01],
#          [-1.19163818e+01, -1.23542175e+01, -1.27190857e+01,
#           -1.29755859e+01, -1.31237183e+01],
#          [-6.78460693e+00, -7.09960938e+00, -7.41876221e+00,
#           -7.67901611e+00, -7.88027954e+00]],
#
#         [[-3.52633820e+01, -3.56148529e+01, -3.56166077e+01,
#           -3.59732819e+01, -3.59750519e+01],
#          [-3.46238098e+01, -3.49775696e+01, -3.53331757e+01,
#           -3.56892242e+01, -3.60456848e+01],
#          [-3.30407867e+01, -3.37142792e+01, -3.43906708e+01,
#           -3.50708160e+01, -3.57546844e+01],
# ...
#          [-1.12636719e+01, -1.19668884e+01, -1.28386841e+01,
#           -1.37472839e+01, -1.44175110e+01],
#          [-2.56958008e-01, -3.45581055e-01, -6.09252930e-01,
#           -1.00253296e+00, -1.35873413e+00],
#          [ 1.67633057e-01,  1.12030029e-01,  1.79687500e-01,
#            2.94250488e-01,  3.28857422e-01]],
#
#         [[-4.22594910e+01, -4.22562103e+01, -4.22437592e+01,
#           -4.22358856e+01, -4.22228241e+01],
#          [-4.00247650e+01, -4.01418152e+01, -4.01743927e+01,
#           -4.02709198e+01, -4.03198547e+01],
#          [-3.76723175e+01, -3.78773041e+01, -3.80621643e+01,
#           -3.81877136e+01, -3.83145447e+01],
#          ...,
#          [-1.01842957e+01, -1.08587036e+01, -1.16497192e+01,
#           -1.25074463e+01, -1.31671143e+01],
#          [ 4.42626953e-01,  4.22515869e-01,  2.56774902e-01,
#            4.33349609e-03, -2.37457275e-01],
#          [ 2.02087402e-01,  2.02209473e-01,  3.44390869e-01,
#            5.43457031e-01,  6.88659668e-01]]]])
# Coordinates:
#   * time     (time) int64 0 1 2 3 4 5 6 7 8 ... 142 143 144 145 146 147 148 149
#   * lon      (lon) float32 1.25 3.75 6.25 8.75 11.25
#   * lat      (lat) float32 -88.75 -86.25 -83.75 -81.25 ... -71.25 -68.75 -66.25
#     height   float64 ...
#   * model    (model) object 'ccsm3' 'cesm104' ... 'mpiesm11' 'mpiesm12'
# Attributes:
#     length:   2120
# - Detrending data using POLYNOMIAL with order=4
# - func1d = polynomaial_fit
# functools.partial(<function polynomaial_fit at 0x7f9566a92c10>, order=4)
# - Calculting the rolling signal
# - window=20, min_periods=20
# data=
# <xarray.DataArray (model: 7, time: 150, lat: 10, lon: 5)>
# array([[[[-3.64356537e+01, -3.68105774e+01, -3.68124542e+01,
#           -3.71937714e+01, -3.71956482e+01],
#          [-3.58370667e+01, -3.62205505e+01, -3.66047668e+01,
#           -3.69874573e+01, -3.73686218e+01],
#          [-3.43840637e+01, -3.51145782e+01, -3.58551483e+01,
#           -3.65926666e+01, -3.73271027e+01],
#          ...,
#          [-1.85668793e+01, -1.93369598e+01, -1.99259491e+01,
#           -2.05832062e+01, -2.13087311e+01],
#          [-1.19163818e+01, -1.23542175e+01, -1.27190857e+01,
#           -1.29755859e+01, -1.31237183e+01],
#          [-6.78460693e+00, -7.09960938e+00, -7.41876221e+00,
#           -7.67901611e+00, -7.88027954e+00]],
#
#         [[-3.52633820e+01, -3.56148529e+01, -3.56166077e+01,
#           -3.59732819e+01, -3.59750519e+01],
#          [-3.46238098e+01, -3.49775696e+01, -3.53331757e+01,
#           -3.56892242e+01, -3.60456848e+01],
#          [-3.30407867e+01, -3.37142792e+01, -3.43906708e+01,
#           -3.50708160e+01, -3.57546844e+01],
# ...
#          [-1.12636719e+01, -1.19668884e+01, -1.28386841e+01,
#           -1.37472839e+01, -1.44175110e+01],
#          [-2.56958008e-01, -3.45581055e-01, -6.09252930e-01,
#           -1.00253296e+00, -1.35873413e+00],
#          [ 1.67633057e-01,  1.12030029e-01,  1.79687500e-01,
#            2.94250488e-01,  3.28857422e-01]],
#
#         [[-4.22594910e+01, -4.22562103e+01, -4.22437592e+01,
#           -4.22358856e+01, -4.22228241e+01],
#          [-4.00247650e+01, -4.01418152e+01, -4.01743927e+01,
#           -4.02709198e+01, -4.03198547e+01],
#          [-3.76723175e+01, -3.78773041e+01, -3.80621643e+01,
#           -3.81877136e+01, -3.83145447e+01],
#          ...,
#          [-1.01842957e+01, -1.08587036e+01, -1.16497192e+01,
#           -1.25074463e+01, -1.31671143e+01],
#          [ 4.42626953e-01,  4.22515869e-01,  2.56774902e-01,
#            4.33349609e-03, -2.37457275e-01],
#          [ 2.02087402e-01,  2.02209473e-01,  3.44390869e-01,
#            5.43457031e-01,  6.88659668e-01]]]])
# Coordinates:
#   * time     (time) int64 0 1 2 3 4 5 6 7 8 ... 142 143 144 145 146 147 148 149
#   * lon      (lon) float32 1.25 3.75 6.25 8.75 11.25
#   * lat      (lat) float32 -88.75 -86.25 -83.75 -81.25 ... -71.25 -68.75 -66.25
#     height   float64 ...
#   * model    (model) object 'ccsm3' 'cesm104' ... 'mpiesm11' 'mpiesm12'
# Attributes:
#     length:   2120
# - Adjusting time points by 9
# - Calculting the rolling noise
# - Adjusting time points by 9
# - Calculating signal to noise

# %%
sn_ds2 = sn.calculate_multi_window_signal_to_noise(test_da, windows=[22, 24, 26], logginglevel='INFO', 
                                          detrend_kwargs={'method':'polynomial'}, parallel=False)
# Out:
# - -- Running function calculate_multi_window_signal_to_noise
# - Detrending required
# - Detrending data using {'method': 'polynomial'}
# - Detrending data using POLYNOMIAL with order=1
# - -- Running function synchronous_calculate_multi_window_signal_to_noise
# - inner_func - windows=[22, 24, 26]
# - window=22
# - -- Running function calculate_rolling_signal_to_noise
# - Detrending required
# - Detrend data provided
# - Calculting the rolling signal
# - Adjusting time points by 10
# - Calculting the rolling noise
# - Adjusting time points by 10
# - Calculating signal to noise
# - window=24
# - -- Running function calculate_rolling_signal_to_noise
# - Detrending required
# - Detrend data provided
# - Calculting the rolling signal
# - Adjusting time points by 11
# - Calculting the rolling noise
# - Adjusting time points by 11
# - Calculating signal to noise
# - window=26
# - -- Running function calculate_rolling_signal_to_noise
# - Detrending required
# - Detrend data provided
# - Calculting the rolling signal
# - Adjusting time points by 12
# - Calculting the rolling noise
# - Adjusting time points by 12
# - Calculating signal to noise

# %%
test_fit = stats.trend_fit(test_da, method='polynomial', order=6)

# %%
test_fit.isel(model=1, lat=1, lon=1).plot(label='fit')
test_da.isel(model=1, lat=1, lon=1).plot(label='raw')
plt.legend()

# %%
sn_ds3 = sn.calculate_multi_window_signal_to_noise(test_da, windows=[22, 24, 26], logginglevel='INFO',
                                                   detrended_da = da-test_fit,
                                                   parallel=False)
# Out:
# - -- Running function calculate_multi_window_signal_to_noise
# - Detrending required
# - Detrend data provided
# - -- Running function synchronous_calculate_multi_window_signal_to_noise
# - inner_func - windows=[22, 24, 26]
# - window=22
# - -- Running function calculate_rolling_signal_to_noise
# - Detrending required
# - Detrend data provided
# - Calculting the rolling signal
# - Adjusting time points by 10
# - Calculting the rolling noise
# - Adjusting time points by 10
# - Calculating signal to noise
# - window=24
# - -- Running function calculate_rolling_signal_to_noise
# - Detrending required
# - Detrend data provided
# - Calculting the rolling signal
# - Adjusting time points by 11
# - Calculting the rolling noise
# - Adjusting time points by 11
# - Calculating signal to noise
# - window=26
# - -- Running function calculate_rolling_signal_to_noise
# - Detrending required
# - Detrend data provided
# - Calculting the rolling signal
# - Adjusting time points by 12
# - Calculting the rolling noise
# - Adjusting time points by 12
# - Calculating signal to noise

# %%
sn_ds3 = sn.calculate_multi_window_rolling_signal_to_nosie_and_bounds(
    experiment_da=test_da, control_da=test_pi ,
    windows=[20, 22, 24], detrend_kwargs={'method': 'polynomial'}, logginglevel='INFO')
# Out:
# -
# Experiment
# --------
#
# windows=[20, 22, 24]
# - synchronous_calculate_multi_window_signal_to_noise - windows=[20, 22, 24]
# - window=20
# - Detrending required
# - Detrending data with {}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[321], line 1
# ----> 1 sn_ds3 = sn.calculate_multi_window_rolling_signal_to_nosie_and_bounds(
#       2     experiment_da=test_da, control_da=test_pi ,
#       3     windows=[20, 22, 24], detrend_kwargs={'method': 'polynomial'}, logginglevel='INFO')
#
# File ~/Documents/PhD/modules/signal_to_noise.py:266, in calculate_multi_window_rolling_signal_to_nosie_and_bounds(experiment_da, control_da, detrend_kwargs, detrended_da, detrend, windows, start_window, end_window, step_window, parallel, logginglevel, return_all)
#     263 logger.debug(f'{sn_kwargs}')
#     265 logger.info('\nExperiment\n--------\n')
# --> 266 experiment_da_sn = calculate_multi_window_signal_to_noise(
#     267     da=experiment_da, detrended_da=detrended_da, **sn_kwargs)
#     269 logger.info('\nControl\n------\n')
#     270 control_sn = calculate_multi_window_signal_to_noise(da=control_da, detrend=False, **sn_kwargs)
#
# File ~/Documents/PhD/modules/signal_to_noise.py:229, in calculate_multi_window_signal_to_noise(da, windows, detrend_kwargs, detrend, start_window, end_window, step_window, parallel, detrended_da, logginglevel)
#     225 if parallel:
#     226     func_calculate_multi_window_signal_to_noise = parallel_calculate_multi_window_signal_to_noise
# --> 229 to_concat = func_calculate_multi_window_signal_to_noise(
#     230     da=da, detrended_da=detrended_da, detrend=detrend, detrend_kwargs=detrend_kwargs,
#     231     windows=windows,logginglevel=logginglevel)
#     234 if len(to_concat) > 1: # We have ran more than one window
#     235     da_multi_window = xr.concat(to_concat, dim='window')
#
# File ~/Documents/PhD/modules/signal_to_noise.py:178, in synchronous_calculate_multi_window_signal_to_noise(da, windows, detrend, detrended_da, detrend_kwargs, logginglevel)
#     176 for window in windows:
#     177     logger.info(f'{window=}')
# --> 178     ds_sn = calculate_rolling_signal_to_noise(da=da, detrended_da=detrended_da, window=window,
#     179                                           detrend=detrend, detrend_kwargs=detrend_kwargs, logginglevel=logginglevel)
#     181     to_concat.append(ds_sn)
#     183 return to_concat
#
# File ~/Documents/PhD/modules/signal_to_noise.py:150, in calculate_rolling_signal_to_noise(window, da, detrended_da, logginglevel, detrend, detrend_kwargs)
#     144     '''
#     145     Window first for multiprocessing reasons.
#     146     Calculates the rolling signal to nosie with an optional detrend
#     147     '''
#     148     utils.change_logging_level(logginglevel)
# --> 150     noise_da = allocate_data_for_noise_calculation(da=da, detrended_da=detrended_da,detrend_kwargs=detrend_kwargs,
#     151                                                    detrend=detrend, logginglevel=logginglevel)
#     153 #     if isinstance(da, xr.DataArray): da = da.to_dataset()
#     154 #     if isinstance(noise_da, xr.DataArray): noise_da = noise_da.to_dataset()
#     156     signal_da = da.sn.calculate_rolling_signal(window=window, logginglevel=logginglevel)
#
# File ~/Documents/PhD/modules/signal_to_noise.py:136, in allocate_data_for_noise_calculation(da, detrended_da, detrend_kwargs, detrend, logginglevel)
#     134     else:
#     135         logger.info(f'Detrending data with {detrend_kwargs}')
# --> 136         noise_da = stats.trend_fit(da, logginglevel=logginglevel, **detrend_kwargs)
#     138 return noise_da
#
# File ~/Documents/PhD/modules/stats.py:87, in trend_fit(da, method, order, lowess_window, func_kwargs, logginglevel)
#      84 utils.change_logging_level(logginglevel)
#      86 if not method:
# ---> 87     raise ValueError(f'method must be specified. Method options:  {[i.value for i in classes.detrendingMethods]}')
#      89 if da.chunks is not None:
#      90     da = da.unify_chunks()#.chunk({'time':-1})
#
# ValueError: method must be specified. Method options:  ['polynomial', 'lowess']
